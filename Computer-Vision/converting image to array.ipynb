# %%
import numpy as np # array

# %%
import matplotlib.pyplot as plt # visualization

# %%
from PIL import Image # python image library

# %%
feature_image = Image.open(r'C:\Users\LIKHITH\Downloads\pic.jpg')

# %%
feature_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=408x612>

# %%
myimage=Image.open(r'C:\Users\LIKHITH\OneDrive\Pictures\Camera imports\2025-10-18 (1)\IMG_20240409_220231_980.jpg')
myimage
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1635x1635>

# %%
print(type(feature_image))
print(type(myimage))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
fea_arr=np.asarray(feature_image)
fea_arr
# Out:
# array([[[ 55,  71,  24],
#         [ 56,  72,  23],
#         [ 58,  74,  25],
#         ...,
#         [ 46,  50,  36],
#         [ 42,  48,  34],
#         [ 41,  47,  33]],
#
#        [[ 54,  70,  23],
#         [ 56,  72,  25],
#         [ 57,  73,  24],
#         ...,
#         [ 46,  50,  36],
#         [ 42,  48,  34],
#         [ 42,  48,  34]],
#
#        [[ 54,  70,  25],
#         [ 55,  71,  24],
#         [ 57,  73,  26],
#         ...,
#         [ 46,  50,  36],
#         [ 43,  49,  35],
#         [ 42,  48,  34]],
#
#        ...,
#
#        [[ 32, 103,  37],
#         [ 24, 103,  37],
#         [ 14, 103,  37],
#         ...,
#         [ 24,  35,  41],
#         [ 25,  36,  42],
#         [ 25,  36,  42]],
#
#        [[ 26, 101,  36],
#         [ 21, 102,  36],
#         [ 15, 104,  38],
#         ...,
#         [ 18,  29,  35],
#         [ 18,  29,  35],
#         [ 19,  30,  36]],
#
#        [[ 20,  99,  34],
#         [ 19, 101,  35],
#         [ 16, 105,  37],
# ...

# %%
plt.imshow(fea_arr)
plt.show()

# %%
fea_arr.shape
# Out:
# (612, 408, 3)

# %%
my_arr =np.asarray(myimage)
my_arr
# Out:
# array([[[231, 255, 255],
#         [231, 255, 255],
#         [231, 255, 255],
#         ...,
#         [153, 181, 218],
#         [156, 184, 221],
#         [159, 187, 224]],
#
#        [[231, 255, 255],
#         [231, 255, 255],
#         [231, 255, 255],
#         ...,
#         [133, 165, 203],
#         [136, 168, 206],
#         [140, 172, 210]],
#
#        [[231, 255, 255],
#         [231, 255, 255],
#         [231, 255, 255],
#         ...,
#         [116, 151, 191],
#         [119, 154, 194],
#         [123, 158, 198]],
#
#        ...,
#
#        [[129, 195,   1],
#         [128, 190,   1],
#         [131, 191,   7],
#         ...,
#         [224, 242, 252],
#         [216, 234, 244],
#         [215, 233, 243]],
#
#        [[133, 199,   5],
#         [130, 192,   3],
#         [129, 189,   5],
#         ...,
#         [222, 240, 250],
#         [213, 231, 241],
#         [213, 231, 241]],
#
#        [[138, 204,   8],
#         [131, 194,   2],
#         [126, 186,   2],
# ...

# %%
plt.imshow(my_arr)
plt.show()

# %%
my_arr.shape
# Out:
# (1635, 1635, 3)
