# %%
import cv2

# %%
import numpy as np

# %%
input = cv2.imread(r"C:\Users\LIKHITH\OneDrive\Pictures\Ele.jpg")

# %%
input
# Out:
# array([[[203, 175, 152],
#         [203, 175, 152],
#         [203, 175, 152],
#         ...,
#         [199, 172, 143],
#         [199, 172, 143],
#         [199, 172, 143]],
#
#        [[203, 175, 152],
#         [203, 175, 152],
#         [203, 175, 152],
#         ...,
#         [199, 172, 143],
#         [199, 172, 143],
#         [199, 172, 143]],
#
#        [[203, 175, 152],
#         [203, 175, 152],
#         [203, 175, 152],
#         ...,
#         [199, 172, 143],
#         [199, 172, 143],
#         [199, 172, 143]],
#
#        ...,
#
#        [[139, 139, 137],
#         [139, 139, 137],
#         [140, 141, 138],
#         ...,
#         [116, 125, 119],
#         [117, 127, 119],
#         [120, 129, 121]],
#
#        [[144, 145, 143],
#         [144, 145, 143],
#         [144, 145, 143],
#         ...,
#         [117, 126, 120],
#         [119, 128, 120],
#         [122, 132, 123]],
#
#        [[149, 150, 147],
#         [149, 150, 147],
#         [149, 150, 147],
#         ...,
#         [119, 127, 121],
#         [122, 132, 123],
#         [127, 136, 128]]], shape=(355, 474, 3), dtype=uint8)

# %%
cv2.imshow('Elephant', input)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
print('Height of the image:', int(input.shape[0]), 'pixels')
print('Width of the image:', int(input.shape[1]), 'pixels')
# Out:
# Height of the image: 355 pixels
# Width of the image: 474 pixels

# %%
cv2.imwrite('output.png', input)
# Out:
# True

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\LIKHITH\\OneDrive\\Desktop\\Data science'
