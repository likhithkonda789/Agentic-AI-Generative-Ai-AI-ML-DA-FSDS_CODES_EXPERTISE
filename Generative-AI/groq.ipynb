# %%
pip install langgraph langchain
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install langchain langchain-groq langchain_community
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
groq_api_key = "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"

# %%
from langchain_groq import ChatGroq

# %%
llm=ChatGroq(groq_api_key=groq_api_key, model_name="llama-3.3-70b-versatile")
llm
# Out:
# ChatGroq(profile={'max_input_tokens': 131072, 'max_output_tokens': 32768, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x0000026C1BB9B8C0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x0000026C1BD4C6E0>, model_name='llama-3.3-70b-versatile', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
from typing import Annotated
from typing_extensions import TypedDict
from langgraph.graph import StateGraph,START,END
from langgraph.graph.message import add_messages

# %%
class State(TypedDict):
  # Messages have the type "list". The `add_messages` function
    # in the annotation defines how this state key should be updated
    # (in this case, it appends messages to the list, rather than overwriting them)
  messages:Annotated[list,add_messages]

graph_builder=StateGraph(State)

# %%
graph_builder

# %%
def chatbot(state:State):
 return {"messages": state["messages"] + ["Hello, World!"]}

# %%
graph_builder.add_edge("START",chatbot)
graph_builder.add_edge("chatbox",END)

# %%
graph=graph_builder.compile()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 graph=graph_builder.compile()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langgraph\graph\state.py:1113, in StateGraph.compile(self, checkpointer, cache, store, interrupt_before, interrupt_after, debug, name)
#    1110 interrupt_after = interrupt_after or []
#    1112 # validate the graph
# -> 1113 self.validate(
#    1114     interrupt=(
#    1115         (interrupt_before if interrupt_before != "*" else []) + interrupt_after
#    1116         if interrupt_after != "*"
#    1117         else []
#    1118     )
#    1119 )
#    1121 # prepare output channels
#    1122 output_channels = (
#    1123     "__root__"
#    1124     if len(self.schemas[self.output_schema]) == 1
#    (...)
#    1130     ]
#    1131 )
#
# ...

# %%
from Ipythton.display import Image display
Image(graph.visualize())
# Out:
#   Cell In[18], line 1
#     from Ipythton.display import Image display
#                                        ^
# SyntaxError: invalid syntax
