# %%
pip install -U langgraph
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting langgraph
#   Downloading langgraph-1.1.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting langchain-core>=0.1 (from langgraph)
#   Downloading langchain_core-1.2.18-py3-none-any.whl.metadata (4.4 kB)
# Collecting langgraph-checkpoint<5.0.0,>=2.1.0 (from langgraph)
#   Downloading langgraph_checkpoint-4.0.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.8 (from langgraph)
#   Downloading langgraph_prebuilt-1.0.8-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph)
#   Downloading langgraph_sdk-0.3.11-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: pydantic>=2.7.4 in C:\Users\LIKHITH\AppData\Roaming\Python\Python313\site-packages (from langgraph) (2.12.4)
# Collecting xxhash>=3.5.0 (from langgraph)
#   Downloading xxhash-3.6.0-cp313-cp313-win_amd64.whl.metadata (13 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph)
#   Downloading ormsgpack-1.12.2-cp313-cp313-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: httpx>=0.25.2 in c:\ProgramData\anaconda3\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.28.1)
# Collecting orjson>=3.11.5 (from langgraph-sdk<0.4.0,>=0.3.0->langgraph)
#   Downloading orjson-3.11.7-cp313-cp313-win_amd64.whl.metadata (43 kB)
# Requirement already satisfied: anyio in c:\ProgramData\anaconda3\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (4.7.0)
# Requirement already satisfied: certifi in c:\ProgramData\anaconda3\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\ProgramData\anaconda3\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.0.9)
# Requirement already satisfied: idna in c:\ProgramData\anaconda3\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\ProgramData\anaconda3\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\ProgramData\anaconda3\Lib\site-packages (from langchain-core>=0.1->langgraph) (1.33)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core>=0.1->langgraph)
#   Downloading langsmith-0.7.16-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging>=23.2.0 in c:\ProgramData\anaconda3\Lib\site-packages (from langchain-core>=0.1->langgraph) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\ProgramData\anaconda3\Lib\site-packages (from langchain-core>=0.1->langgraph) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\ProgramData\anaconda3\Lib\site-packages (from langchain-core>=0.1->langgraph) (9.0.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\LIKHITH\AppData\Roaming\Python\Python313\site-packages (from langchain-core>=0.1->langgraph) (4.15.0)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core>=0.1->langgraph)
#   Downloading uuid_utils-0.14.1-cp39-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: jsonpointer>=1.9 in c:\ProgramData\anaconda3\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.1->langgraph) (2.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\ProgramData\anaconda3\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\ProgramData\anaconda3\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (2.32.3)
# Requirement already satisfied: zstandard>=0.23.0 in c:\ProgramData\anaconda3\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\ProgramData\anaconda3\Lib\site-packages (from pydantic>=2.7.4->langgraph) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\LIKHITH\AppData\Roaming\Python\Python313\site-packages (from pydantic>=2.7.4->langgraph) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\LIKHITH\AppData\Roaming\Python\Python313\site-packages (from pydantic>=2.7.4->langgraph) (0.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\ProgramData\anaconda3\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\ProgramData\anaconda3\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\ProgramData\anaconda3\Lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.3.0)
# Downloading langgraph-1.1.1-py3-none-any.whl (167 kB)
# Downloading langgraph_checkpoint-4.0.1-py3-none-any.whl (50 kB)
# Downloading langgraph_prebuilt-1.0.8-py3-none-any.whl (35 kB)
# Downloading langgraph_sdk-0.3.11-py3-none-any.whl (94 kB)
# Downloading langchain_core-1.2.18-py3-none-any.whl (503 kB)
# Downloading langsmith-0.7.16-py3-none-any.whl (347 kB)
# Downloading uuid_utils-0.14.1-cp39-abi3-win_amd64.whl (187 kB)
# Downloading orjson-3.11.7-cp313-cp313-win_amd64.whl (124 kB)
# Downloading ormsgpack-1.12.2-cp313-cp313-win_amd64.whl (117 kB)
# Downloading xxhash-3.6.0-cp313-cp313-win_amd64.whl (31 kB)
# Installing collected packages: xxhash, uuid-utils, ormsgpack, orjson, langsmith, langgraph-sdk, langchain-core, langgraph-checkpoint, langgraph-prebuilt, langgraph
#
#    ---- -----------------------------------  1/10 [uuid-utils]
#   Attempting uninstall: orjson
#    ---- -----------------------------------  1/10 [uuid-utils]
#     Found existing installation: orjson 3.11.4
#    ---- -----------------------------------  1/10 [uuid-utils]
#     Uninstalling orjson-3.11.4:
#    ---- -----------------------------------  1/10 [uuid-utils]
#       Successfully uninstalled orjson-3.11.4
#    ---- -----------------------------------  1/10 [uuid-utils]
#    ------------ ---------------------------  3/10 [orjson]
#    ---------------- -----------------------  4/10 [langsmith]
#    ---------------- -----------------------  4/10 [langsmith]
#    ---------------- -----------------------  4/10 [langsmith]
#    ---------------- -----------------------  4/10 [langsmith]
#    ---------------- -----------------------  4/10 [langsmith]
#    ---------------- -----------------------  4/10 [langsmith]
#    ---------------- -----------------------  4/10 [langsmith]
#    ---------------- -----------------------  4/10 [langsmith]
#    ---------------- -----------------------  4/10 [langsmith]
#    ---------------- -----------------------  4/10 [langsmith]
#    ---------------- -----------------------  4/10 [langsmith]
#    ---------------- -----------------------  4/10 [langsmith]
#    ---------------- -----------------------  4/10 [langsmith]
#    ---------------- -----------------------  4/10 [langsmith]
#    ---------------- -----------------------  4/10 [langsmith]
#    ---------------- -----------------------  4/10 [langsmith]
#    ---------------- -----------------------  4/10 [langsmith]
#    ---------------- -----------------------  4/10 [langsmith]
#    ---------------- -----------------------  4/10 [langsmith]
#    -------------------- -------------------  5/10 [langgraph-sdk]
#    -------------------- -------------------  5/10 [langgraph-sdk]
#    -------------------- -------------------  5/10 [langgraph-sdk]
#    -------------------- -------------------  5/10 [langgraph-sdk]
#    -------------------- -------------------  5/10 [langgraph-sdk]
#    -------------------- -------------------  5/10 [langgraph-sdk]
#    -------------------- -------------------  5/10 [langgraph-sdk]
#    -------------------- -------------------  5/10 [langgraph-sdk]
#    ------------------------ ---------------  6/10 [langchain-core]
#    ------------------------ ---------------  6/10 [langchain-core]
#    ------------------------ ---------------  6/10 [langchain-core]
#    ------------------------ ---------------  6/10 [langchain-core]
#    ------------------------ ---------------  6/10 [langchain-core]
#    ------------------------ ---------------  6/10 [langchain-core]
#    ------------------------ ---------------  6/10 [langchain-core]
#    ------------------------ ---------------  6/10 [langchain-core]
#    ------------------------ ---------------  6/10 [langchain-core]
#    ------------------------ ---------------  6/10 [langchain-core]
#    ------------------------ ---------------  6/10 [langchain-core]
#    ------------------------ ---------------  6/10 [langchain-core]
#    ------------------------ ---------------  6/10 [langchain-core]
#    ------------------------ ---------------  6/10 [langchain-core]
#    ------------------------ ---------------  6/10 [langchain-core]
#    ------------------------ ---------------  6/10 [langchain-core]
#    ------------------------ ---------------  6/10 [langchain-core]
#    ------------------------ ---------------  6/10 [langchain-core]
#    ------------------------ ---------------  6/10 [langchain-core]
#    ------------------------ ---------------  6/10 [langchain-core]
#    ------------------------ ---------------  6/10 [langchain-core]
#    ------------------------ ---------------  6/10 [langchain-core]
#    ------------------------ ---------------  6/10 [langchain-core]
#    ------------------------ ---------------  6/10 [langchain-core]
#    ------------------------ ---------------  6/10 [langchain-core]
#    ------------------------ ---------------  6/10 [langchain-core]
#    ------------------------ ---------------  6/10 [langchain-core]
#    ------------------------ ---------------  6/10 [langchain-core]
#    ------------------------ ---------------  6/10 [langchain-core]
#    ------------------------ ---------------  6/10 [langchain-core]
#    ------------------------ ---------------  6/10 [langchain-core]
#    ------------------------ ---------------  6/10 [langchain-core]
#    ------------------------ ---------------  6/10 [langchain-core]
#    ------------------------ ---------------  6/10 [langchain-core]
#    ------------------------ ---------------  6/10 [langchain-core]
#    ---------------------------- -----------  7/10 [langgraph-checkpoint]
#    ---------------------------- -----------  7/10 [langgraph-checkpoint]
#    ---------------------------- -----------  7/10 [langgraph-checkpoint]
#    ---------------------------- -----------  7/10 [langgraph-checkpoint]
#    -------------------------------- -------  8/10 [langgraph-prebuilt]
#    ------------------------------------ ---  9/10 [langgraph]
#    ------------------------------------ ---  9/10 [langgraph]
#    ------------------------------------ ---  9/10 [langgraph]
#    ------------------------------------ ---  9/10 [langgraph]
#    ------------------------------------ ---  9/10 [langgraph]
#    ------------------------------------ ---  9/10 [langgraph]
#    ------------------------------------ ---  9/10 [langgraph]
#    ------------------------------------ ---  9/10 [langgraph]
#    ------------------------------------ ---  9/10 [langgraph]
#    ------------------------------------ ---  9/10 [langgraph]
#    ------------------------------------ ---  9/10 [langgraph]
#    ------------------------------------ ---  9/10 [langgraph]
#    ------------------------------------ ---  9/10 [langgraph]
#    ---------------------------------------- 10/10 [langgraph]
#
# Successfully installed langchain-core-1.2.18 langgraph-1.1.1 langgraph-checkpoint-4.0.1 langgraph-prebuilt-1.0.8 langgraph-sdk-0.3.11 langsmith-0.7.16 orjson-3.11.7 ormsgpack-1.12.2 uuid-utils-0.14.1 xxhash-3.6.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict
from IPython.display import Image, display

# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict
from IPython.display import Image, display




class MyState(TypedDict):
    message: str

# Define the start node
def start_node(state: MyState) -> MyState:
    print("Start node received:", state["message"])
    # Process or pass the message to the end node
    return {"message": state["message"] + " -> processed by start"}

# Define the end node
def end_node(state: MyState) -> MyState:
    print("End node received:", state["message"])
    return state

# Build the graph
builder = StateGraph(MyState)


# Define the end node
#def end_node(state: MyState) -> MyState:
#    print("End node received:", state["message"])
#    return state

# %%
builder = StateGraph

# %%
builder
# Out:
# langgraph.graph.state.StateGraph

# %%
builder.add_node("start", start_node)
builder.add_node("end", end_node)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 builder.add_node("start", start_node)
#       2 builder.add_node("end", end_node)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langgraph\graph\state.py:676, in StateGraph.add_node(self, node, action, defer, metadata, input_schema, retry_policy, cache_policy, destinations, **kwargs)
#     672     if node is None:
#     673         raise ValueError(
#     674             "Node name must be provided if action is not a function"
#     675         )
# --> 676 if self.compiled:
#     677     logger.warning(
#     678         "Adding a node to a graph that has already been compiled. This will "
#     679         "not be reflected in the compiled graph."
#     680     )
#     681 if not isinstance(node, str):
#
# AttributeError: 'str' object has no attribute 'compiled'

# %%
builder.set_entry_point("start")
builder.add_edge("start", "end")
builder.add_edge("end", END)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 builder.set_entry_point("start")
#       2 builder.add_edge("start", "end")
#       3 builder.add_edge("end", END)
#
# TypeError: StateGraph.set_entry_point() missing 1 required positional argument: 'key'

# %%
graph = builder.compile()
result = graph.invoke({"message": "Hello, World!"})
print("Final result:", result["message"])
