# %%
pip install spacy
# Out:
# Collecting spacy
#   Downloading spacy-3.8.13-cp311-cp311-win_amd64.whl.metadata (28 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.15-cp311-cp311-win_amd64.whl.metadata (2.3 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.13-cp311-cp311-win_amd64.whl.metadata (9.9 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.13-cp311-cp311-win_amd64.whl.metadata (5.4 kB)
# Collecting thinc<8.4.0,>=8.3.12 (from spacy)
#   Downloading thinc-8.3.13-cp311-cp311-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Using cached wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.5.3 (from spacy)
#   Downloading srsly-2.5.3-cp311-cp311-win_amd64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Using cached catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<2.0.0,>=1.0.0 (from spacy)
#   Downloading weasel-1.0.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting confection<2.0.0,>=1.3.2 (from spacy)
#   Downloading confection-1.3.3-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\Users\LIKHITH\AppData\Local\Programs\Python\Python311\Lib\site-packages (from spacy) (0.24.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\Users\LIKHITH\AppData\Local\Programs\Python\Python311\Lib\site-packages (from spacy) (4.67.3)
# Requirement already satisfied: numpy>=1.19.0 in c:\Users\LIKHITH\AppData\Local\Programs\Python\Python311\Lib\site-packages (from spacy) (2.4.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\Users\LIKHITH\AppData\Local\Programs\Python\Python311\Lib\site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\Users\LIKHITH\AppData\Local\Programs\Python\Python311\Lib\site-packages (from spacy) (2.12.5)
# Requirement already satisfied: jinja2 in c:\Users\LIKHITH\AppData\Local\Programs\Python\Python311\Lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in c:\Users\LIKHITH\AppData\Local\Programs\Python\Python311\Lib\site-packages (from spacy) (65.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\Users\LIKHITH\AppData\Local\Programs\Python\Python311\Lib\site-packages (from spacy) (26.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\LIKHITH\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\Users\LIKHITH\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\Users\LIKHITH\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\LIKHITH\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\LIKHITH\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\LIKHITH\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\Users\LIKHITH\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\Users\LIKHITH\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.1.4)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.12->spacy)
#   Downloading blis-1.3.3-cp311-cp311-win_amd64.whl.metadata (7.7 kB)
# Requirement already satisfied: colorama in c:\Users\LIKHITH\AppData\Local\Programs\Python\Python311\Lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Collecting click>=8.2.1 (from typer<1.0.0,>=0.3.0->spacy)
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: shellingham>=1.3.0 in c:\Users\LIKHITH\AppData\Local\Programs\Python\Python311\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in c:\Users\LIKHITH\AppData\Local\Programs\Python\Python311\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (14.3.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\Users\LIKHITH\AppData\Local\Programs\Python\Python311\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.4)
# Collecting cloudpathlib>=0.7.0 (from weasel<2.0.0,>=1.0.0->spacy)
#   Using cached cloudpathlib-0.23.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: smart-open>=5.2.1 in c:\Users\LIKHITH\AppData\Local\Programs\Python\Python311\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (7.5.1)
# Collecting httpx>=0.24.0 (from weasel<2.0.0,>=1.0.0->spacy)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: anyio in c:\Users\LIKHITH\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.12.1)
# Collecting httpcore==1.* (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\Users\LIKHITH\AppData\Local\Programs\Python\Python311\Lib\site-packages (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\Users\LIKHITH\AppData\Local\Programs\Python\Python311\Lib\site-packages (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\Users\LIKHITH\AppData\Local\Programs\Python\Python311\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: wrapt in c:\Users\LIKHITH\AppData\Local\Programs\Python\Python311\Lib\site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Users\LIKHITH\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jinja2->spacy) (3.0.3)
# Downloading spacy-3.8.13-cp311-cp311-win_amd64.whl (15.4 MB)
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#     --------------------------------------- 0.3/15.4 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/15.4 MB 2.4 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.6/15.4 MB 3.0 MB/s eta 0:00:05
#    ------ --------------------------------- 2.4/15.4 MB 3.2 MB/s eta 0:00:05
#    ------ --------------------------------- 2.6/15.4 MB 3.1 MB/s eta 0:00:05
#    -------- ------------------------------- 3.4/15.4 MB 2.9 MB/s eta 0:00:05
#    ---------- ----------------------------- 3.9/15.4 MB 2.9 MB/s eta 0:00:04
#    ----------- ---------------------------- 4.5/15.4 MB 2.9 MB/s eta 0:00:04
#    ------------- -------------------------- 5.2/15.4 MB 2.9 MB/s eta 0:00:04
#    -------------- ------------------------- 5.5/15.4 MB 2.9 MB/s eta 0:00:04
#    --------------- ------------------------ 6.0/15.4 MB 2.8 MB/s eta 0:00:04
#    ---------------- ----------------------- 6.3/15.4 MB 2.7 MB/s eta 0:00:04
#    ---------------- ----------------------- 6.3/15.4 MB 2.7 MB/s eta 0:00:04
#    ------------------- -------------------- 7.3/15.4 MB 2.5 MB/s eta 0:00:04
#    --------------------- ------------------ 8.1/15.4 MB 2.6 MB/s eta 0:00:03
#    ---------------------- ----------------- 8.7/15.4 MB 2.6 MB/s eta 0:00:03
#    ------------------------ --------------- 9.4/15.4 MB 2.7 MB/s eta 0:00:03
#    ------------------------- -------------- 10.0/15.4 MB 2.7 MB/s eta 0:00:02
#    --------------------------- ------------ 10.7/15.4 MB 2.7 MB/s eta 0:00:02
#    ------------------------------ --------- 11.5/15.4 MB 2.8 MB/s eta 0:00:02
#    ------------------------------- -------- 12.1/15.4 MB 2.8 MB/s eta 0:00:02
#    -------------------------------- ------- 12.6/15.4 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.1/15.4 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.4/15.4 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.4/15.4 MB 2.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.6/15.4 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------ --- 14.2/15.4 MB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 14.7/15.4 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  15.2/15.4 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 15.4/15.4 MB 2.5 MB/s  0:00:06
# Using cached catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading confection-1.3.3-py3-none-any.whl (35 kB)
# Downloading cymem-2.0.13-cp311-cp311-win_amd64.whl (40 kB)
# Downloading murmurhash-1.0.15-cp311-cp311-win_amd64.whl (25 kB)
# Downloading preshed-3.0.13-cp311-cp311-win_amd64.whl (122 kB)
# Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Using cached spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.5.3-cp311-cp311-win_amd64.whl (651 kB)
#    ---------------------------------------- 0.0/651.7 kB ? eta -:--:--
#    -------------------------------- ------- 524.3/651.7 kB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 651.7/651.7 kB 1.3 MB/s  0:00:00
# Downloading thinc-8.3.13-cp311-cp311-win_amd64.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----------------- ---------------------- 0.8/1.8 MB 4.8 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.8/1.8 MB 4.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.0/1.8 MB 1.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.0/1.8 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 1.6 MB/s  0:00:01
# Downloading blis-1.3.3-cp311-cp311-win_amd64.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    ----- ---------------------------------- 0.8/6.2 MB 5.6 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.6/6.2 MB 4.0 MB/s eta 0:00:02
#    --------------- ------------------------ 2.4/6.2 MB 3.6 MB/s eta 0:00:02
#    ------------------ --------------------- 2.9/6.2 MB 3.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.2 MB 3.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.2 MB 3.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.2 MB 3.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.2 MB 3.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.2 MB 3.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.2 MB 3.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.2 MB 3.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.2 MB 3.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.2 MB 3.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.2 MB 3.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.2 MB 3.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.2 MB 3.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.2 MB 3.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.2 MB 3.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.2 MB 3.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.2 MB 3.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.2 MB 3.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.2 MB 3.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.2 MB 3.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.2 MB 3.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.2 MB 3.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.2 MB 3.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.2 MB 3.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.2 MB 3.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.2 MB 3.4 MB/s eta 0:00:01
#    ------------------------- -------------- 3.9/6.2 MB 582.8 kB/s eta 0:00:04
#    --------------------------- ------------ 4.2/6.2 MB 599.1 kB/s eta 0:00:04
#    --------------------------- ------------ 4.2/6.2 MB 599.1 kB/s eta 0:00:04
#    -------------------------------- ------- 5.0/6.2 MB 672.5 kB/s eta 0:00:02
#    --------------------------------- ------ 5.2/6.2 MB 689.9 kB/s eta 0:00:02
#    ----------------------------------- ---- 5.5/6.2 MB 718.5 kB/s eta 0:00:01
#    ------------------------------------- -- 5.8/6.2 MB 730.9 kB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 756.3 kB/s  0:00:07
# Using cached wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-1.0.0-py3-none-any.whl (50 kB)
# Using cached click-8.3.1-py3-none-any.whl (108 kB)
# Using cached cloudpathlib-0.23.0-py3-none-any.whl (62 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Installing collected packages: wasabi, spacy-loggers, spacy-legacy, murmurhash, h11, cymem, confection, cloudpathlib, click, catalogue, blis, srsly, preshed, httpcore, thinc, httpx, weasel, spacy
#
#    ----------------------------------------  0/18 [wasabi]
#    ----------------------------------------  0/18 [wasabi]
#    -- -------------------------------------  1/18 [spacy-loggers]
#    -- -------------------------------------  1/18 [spacy-loggers]
#    ---- -----------------------------------  2/18 [spacy-legacy]
#    ---- -----------------------------------  2/18 [spacy-legacy]
#    ---- -----------------------------------  2/18 [spacy-legacy]
#   Attempting uninstall: h11
#    ---- -----------------------------------  2/18 [spacy-legacy]
#     Found existing installation: h11 0.9.0
#    ---- -----------------------------------  2/18 [spacy-legacy]
#     Uninstalling h11-0.9.0:
#    ---- -----------------------------------  2/18 [spacy-legacy]
#    -------- -------------------------------  4/18 [h11]
#       Successfully uninstalled h11-0.9.0
#    -------- -------------------------------  4/18 [h11]
#    -------- -------------------------------  4/18 [h11]
#    -------- -------------------------------  4/18 [h11]
#    -------- -------------------------------  4/18 [h11]
#    ------------- --------------------------  6/18 [confection]
#    ------------- --------------------------  6/18 [confection]
#    --------------- ------------------------  7/18 [cloudpathlib]
#    --------------- ------------------------  7/18 [cloudpathlib]
#    --------------- ------------------------  7/18 [cloudpathlib]
#    --------------- ------------------------  7/18 [cloudpathlib]
#    --------------- ------------------------  7/18 [cloudpathlib]
#    --------------- ------------------------  7/18 [cloudpathlib]
#   Attempting uninstall: click
#    --------------- ------------------------  7/18 [cloudpathlib]
#     Found existing installation: click 8.1.8
#    --------------- ------------------------  7/18 [cloudpathlib]
#     Uninstalling click-8.1.8:
#    --------------- ------------------------  7/18 [cloudpathlib]
#       Successfully uninstalled click-8.1.8
#    --------------- ------------------------  7/18 [cloudpathlib]
#    ----------------- ----------------------  8/18 [click]
#    ----------------- ----------------------  8/18 [click]
#    ----------------- ----------------------  8/18 [click]
#    ----------------- ----------------------  8/18 [click]
#    -------------------- -------------------  9/18 [catalogue]
#    ---------------------- ----------------- 10/18 [blis]
#    ---------------------- ----------------- 10/18 [blis]
#    ------------------------ --------------- 11/18 [srsly]
#    ------------------------ --------------- 11/18 [srsly]
#    ------------------------ --------------- 11/18 [srsly]
#    ------------------------ --------------- 11/18 [srsly]
#    ------------------------ --------------- 11/18 [srsly]
#    ------------------------ --------------- 11/18 [srsly]
#    ------------------------ --------------- 11/18 [srsly]
#    ------------------------ --------------- 11/18 [srsly]
#    ------------------------ --------------- 11/18 [srsly]
#    ------------------------ --------------- 11/18 [srsly]
#    ------------------------ --------------- 11/18 [srsly]
#    ------------------------ --------------- 11/18 [srsly]
#    ------------------------ --------------- 11/18 [srsly]
#    ------------------------ --------------- 11/18 [srsly]
#    ------------------------ --------------- 11/18 [srsly]
#    ------------------------ --------------- 11/18 [srsly]
#    ------------------------ --------------- 11/18 [srsly]
#    ------------------------ --------------- 11/18 [srsly]
#    ------------------------ --------------- 11/18 [srsly]
#    ------------------------ --------------- 11/18 [srsly]
#    ------------------------ --------------- 11/18 [srsly]
#    -------------------------- ------------- 12/18 [preshed]
#   Attempting uninstall: httpcore
#    -------------------------- ------------- 12/18 [preshed]
#    ---------------------------- ----------- 13/18 [httpcore]
#     Found existing installation: httpcore 0.9.1
#    ---------------------------- ----------- 13/18 [httpcore]
#     Uninstalling httpcore-0.9.1:
#    ---------------------------- ----------- 13/18 [httpcore]
#       Successfully uninstalled httpcore-0.9.1
#    ---------------------------- ----------- 13/18 [httpcore]
#    ---------------------------- ----------- 13/18 [httpcore]
#    ---------------------------- ----------- 13/18 [httpcore]
#    ---------------------------- ----------- 13/18 [httpcore]
#    ---------------------------- ----------- 13/18 [httpcore]
#    ---------------------------- ----------- 13/18 [httpcore]
#    ---------------------------- ----------- 13/18 [httpcore]
#    ---------------------------- ----------- 13/18 [httpcore]
#    ------------------------------- -------- 14/18 [thinc]
#    ------------------------------- -------- 14/18 [thinc]
#    ------------------------------- -------- 14/18 [thinc]
#    ------------------------------- -------- 14/18 [thinc]
#    ------------------------------- -------- 14/18 [thinc]
#    ------------------------------- -------- 14/18 [thinc]
#    ------------------------------- -------- 14/18 [thinc]
#    ------------------------------- -------- 14/18 [thinc]
#    ------------------------------- -------- 14/18 [thinc]
#    ------------------------------- -------- 14/18 [thinc]
#    ------------------------------- -------- 14/18 [thinc]
#    ------------------------------- -------- 14/18 [thinc]
#    ------------------------------- -------- 14/18 [thinc]
#    ------------------------------- -------- 14/18 [thinc]
#    ------------------------------- -------- 14/18 [thinc]
#    ------------------------------- -------- 14/18 [thinc]
#    ------------------------------- -------- 14/18 [thinc]
#    ------------------------------- -------- 14/18 [thinc]
#    ------------------------------- -------- 14/18 [thinc]
#    ------------------------------- -------- 14/18 [thinc]
#    ------------------------------- -------- 14/18 [thinc]
#    ------------------------------- -------- 14/18 [thinc]
#    ------------------------------- -------- 14/18 [thinc]
#    ------------------------------- -------- 14/18 [thinc]
#    ------------------------------- -------- 14/18 [thinc]
#    ------------------------------- -------- 14/18 [thinc]
#   Attempting uninstall: httpx
#    ------------------------------- -------- 14/18 [thinc]
#     Found existing installation: httpx 0.13.3
#    ------------------------------- -------- 14/18 [thinc]
#     Uninstalling httpx-0.13.3:
#    ------------------------------- -------- 14/18 [thinc]
#       Successfully uninstalled httpx-0.13.3
#    ------------------------------- -------- 14/18 [thinc]
#    --------------------------------- ------ 15/18 [httpx]
#    --------------------------------- ------ 15/18 [httpx]
#    --------------------------------- ------ 15/18 [httpx]
#    --------------------------------- ------ 15/18 [httpx]
#    --------------------------------- ------ 15/18 [httpx]
#    --------------------------------- ------ 15/18 [httpx]
#    --------------------------------- ------ 15/18 [httpx]
#    ----------------------------------- ---- 16/18 [weasel]
#    ----------------------------------- ---- 16/18 [weasel]
#    ----------------------------------- ---- 16/18 [weasel]
#    ----------------------------------- ---- 16/18 [weasel]
#    ----------------------------------- ---- 16/18 [weasel]
#    ----------------------------------- ---- 16/18 [weasel]
#    ----------------------------------- ---- 16/18 [weasel]
#    ----------------------------------- ---- 16/18 [weasel]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ---------------------------------------- 18/18 [spacy]
#
# Successfully installed blis-1.3.3 catalogue-2.0.10 click-8.3.1 cloudpathlib-0.23.0 confection-1.3.3 cymem-2.0.13 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 murmurhash-1.0.15 preshed-3.0.13 spacy-3.8.13 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.3 thinc-8.3.13 wasabi-1.1.3 weasel-1.0.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# googletrans 4.0.0rc1 requires httpx==0.13.3, but you have httpx 0.28.1 which is incompatible.
# gtts 2.5.4 requires click<8.2,>=7.1, but you have click 8.3.1 which is incompatible.

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      -- ------------------------------------- 0.8/12.8 MB 6.7 MB/s eta 0:00:02
#      ---- ----------------------------------- 1.3/12.8 MB 5.6 MB/s eta 0:00:03
#      ------- -------------------------------- 2.4/12.8 MB 4.6 MB/s eta 0:00:03
#      --------- ------------------------------ 3.1/12.8 MB 4.4 MB/s eta 0:00:03
#      ------------ --------------------------- 3.9/12.8 MB 4.2 MB/s eta 0:00:03
#      -------------- ------------------------- 4.7/12.8 MB 4.1 MB/s eta 0:00:02
#      ----------------- ---------------------- 5.5/12.8 MB 4.0 MB/s eta 0:00:02
#      ------------------- -------------------- 6.3/12.8 MB 3.9 MB/s eta 0:00:02
#      ---------------------- ----------------- 7.3/12.8 MB 3.9 MB/s eta 0:00:02
#      ------------------------ --------------- 7.9/12.8 MB 3.9 MB/s eta 0:00:02
#      --------------------------- ------------ 8.7/12.8 MB 3.9 MB/s eta 0:00:02
#      ----------------------------- ---------- 9.4/12.8 MB 3.9 MB/s eta 0:00:01
#      ------------------------------- -------- 10.2/12.8 MB 3.8 MB/s eta 0:00:01
#      ---------------------------------- ----- 11.0/12.8 MB 3.8 MB/s eta 0:00:01
#      ------------------------------------ --- 11.8/12.8 MB 3.8 MB/s eta 0:00:01
#      ---------------------------------------  12.6/12.8 MB 3.8 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 3.7 MB/s  0:00:03
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp("data science and ai has greate career ahead")

# %%
pip install pyqt5
# Out:
# Collecting pyqt5
#   Downloading PyQt5-5.15.11-cp38-abi3-win_amd64.whl.metadata (2.1 kB)
# Collecting PyQt5-sip<13,>=12.15 (from pyqt5)
#   Downloading pyqt5_sip-12.18.0-cp311-cp311-win_amd64.whl.metadata (516 bytes)
# Collecting PyQt5-Qt5<5.16.0,>=5.15.2 (from pyqt5)
#   Downloading PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl.metadata (552 bytes)
# Downloading PyQt5-5.15.11-cp38-abi3-win_amd64.whl (6.9 MB)
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/6.9 MB 1.9 MB/s eta 0:00:04
#    ------- -------------------------------- 1.3/6.9 MB 2.6 MB/s eta 0:00:03
#    ---------- ----------------------------- 1.8/6.9 MB 3.0 MB/s eta 0:00:02
#    ---------------- ----------------------- 2.9/6.9 MB 3.2 MB/s eta 0:00:02
#    ------------------ --------------------- 3.1/6.9 MB 3.4 MB/s eta 0:00:02
#    ------------------------ --------------- 4.2/6.9 MB 3.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.0/6.9 MB 3.4 MB/s eta 0:00:01
#    --------------------------------- ------ 5.8/6.9 MB 3.4 MB/s eta 0:00:01
#    -------------------------------------- - 6.6/6.9 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 6.9/6.9 MB 3.3 MB/s  0:00:02
# Downloading PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl (50.1 MB)
#    ---------------------------------------- 0.0/50.1 MB ? eta -:--:--
#    ---------------------------------------- 0.5/50.1 MB 3.4 MB/s eta 0:00:15
#     --------------------------------------- 1.0/50.1 MB 3.0 MB/s eta 0:00:17
#    - -------------------------------------- 1.6/50.1 MB 2.5 MB/s eta 0:00:20
#    - -------------------------------------- 1.8/50.1 MB 2.3 MB/s eta 0:00:22
#    - -------------------------------------- 2.4/50.1 MB 2.3 MB/s eta 0:00:21
#    -- ------------------------------------- 3.1/50.1 MB 2.4 MB/s eta 0:00:20
#    -- ------------------------------------- 3.4/50.1 MB 2.4 MB/s eta 0:00:20
#    --- ------------------------------------ 3.9/50.1 MB 2.3 MB/s eta 0:00:21
#    --- ------------------------------------ 4.2/50.1 MB 2.3 MB/s eta 0:00:21
#    --- ------------------------------------ 4.7/50.1 MB 2.2 MB/s eta 0:00:21
#    ---- ----------------------------------- 5.2/50.1 MB 2.2 MB/s eta 0:00:21
#    ---- ----------------------------------- 5.8/50.1 MB 2.2 MB/s eta 0:00:20
#    ----- ---------------------------------- 6.3/50.1 MB 2.3 MB/s eta 0:00:20
#    ----- ---------------------------------- 7.1/50.1 MB 2.3 MB/s eta 0:00:19
#    ------ --------------------------------- 7.6/50.1 MB 2.3 MB/s eta 0:00:19
#    ------ --------------------------------- 8.1/50.1 MB 2.4 MB/s eta 0:00:18
#    ------- -------------------------------- 8.9/50.1 MB 2.5 MB/s eta 0:00:17
#    ------- -------------------------------- 9.7/50.1 MB 2.5 MB/s eta 0:00:16
#    -------- ------------------------------- 10.5/50.1 MB 2.6 MB/s eta 0:00:16
#    -------- ------------------------------- 11.0/50.1 MB 2.6 MB/s eta 0:00:15
#    --------- ------------------------------ 11.8/50.1 MB 2.6 MB/s eta 0:00:15
#    --------- ------------------------------ 12.3/50.1 MB 2.6 MB/s eta 0:00:15
#    ---------- ----------------------------- 12.8/50.1 MB 2.6 MB/s eta 0:00:15
#    ---------- ----------------------------- 13.1/50.1 MB 2.6 MB/s eta 0:00:15
#    ---------- ----------------------------- 13.4/50.1 MB 2.5 MB/s eta 0:00:15
#    ---------- ----------------------------- 13.6/50.1 MB 2.5 MB/s eta 0:00:15
#    ----------- ---------------------------- 14.2/50.1 MB 2.5 MB/s eta 0:00:15
#    ----------- ---------------------------- 14.4/50.1 MB 2.5 MB/s eta 0:00:15
#    ----------- ---------------------------- 14.9/50.1 MB 2.4 MB/s eta 0:00:15
#    ------------ --------------------------- 15.2/50.1 MB 2.4 MB/s eta 0:00:15
#    ------------ --------------------------- 15.7/50.1 MB 2.4 MB/s eta 0:00:15
#    ------------ --------------------------- 16.0/50.1 MB 2.4 MB/s eta 0:00:15
#    ------------- -------------------------- 16.5/50.1 MB 2.3 MB/s eta 0:00:15
#    ------------- -------------------------- 17.3/50.1 MB 2.4 MB/s eta 0:00:14
#    -------------- ------------------------- 17.8/50.1 MB 2.4 MB/s eta 0:00:14
#    -------------- ------------------------- 18.4/50.1 MB 2.4 MB/s eta 0:00:14
#    --------------- ------------------------ 18.9/50.1 MB 2.4 MB/s eta 0:00:13
#    --------------- ------------------------ 19.4/50.1 MB 2.4 MB/s eta 0:00:13
#    --------------- ------------------------ 19.9/50.1 MB 2.4 MB/s eta 0:00:13
#    ---------------- ----------------------- 20.4/50.1 MB 2.4 MB/s eta 0:00:13
#    ---------------- ----------------------- 21.0/50.1 MB 2.4 MB/s eta 0:00:13
#    ---------------- ----------------------- 21.2/50.1 MB 2.4 MB/s eta 0:00:13
#    ----------------- ---------------------- 22.0/50.1 MB 2.4 MB/s eta 0:00:12
#    ------------------ --------------------- 22.5/50.1 MB 2.4 MB/s eta 0:00:12
#    ------------------ --------------------- 23.1/50.1 MB 2.4 MB/s eta 0:00:12
#    ------------------ --------------------- 23.6/50.1 MB 2.4 MB/s eta 0:00:11
#    ------------------- -------------------- 24.4/50.1 MB 2.4 MB/s eta 0:00:11
#    ------------------- -------------------- 24.9/50.1 MB 2.4 MB/s eta 0:00:11
#    -------------------- ------------------- 25.7/50.1 MB 2.5 MB/s eta 0:00:10
#    -------------------- ------------------- 26.2/50.1 MB 2.5 MB/s eta 0:00:10
#    --------------------- ------------------ 26.7/50.1 MB 2.5 MB/s eta 0:00:10
#    --------------------- ------------------ 27.3/50.1 MB 2.5 MB/s eta 0:00:10
#    ---------------------- ----------------- 28.0/50.1 MB 2.5 MB/s eta 0:00:09
#    ---------------------- ----------------- 28.6/50.1 MB 2.5 MB/s eta 0:00:09
#    ----------------------- ---------------- 29.4/50.1 MB 2.5 MB/s eta 0:00:09
#    ----------------------- ---------------- 29.9/50.1 MB 2.5 MB/s eta 0:00:09
#    ------------------------ --------------- 30.4/50.1 MB 2.5 MB/s eta 0:00:08
#    ------------------------ --------------- 30.7/50.1 MB 2.5 MB/s eta 0:00:08
#    ------------------------- -------------- 31.5/50.1 MB 2.5 MB/s eta 0:00:08
#    ------------------------- -------------- 32.0/50.1 MB 2.5 MB/s eta 0:00:08
#    ------------------------- -------------- 32.5/50.1 MB 2.5 MB/s eta 0:00:07
#    -------------------------- ------------- 33.3/50.1 MB 2.5 MB/s eta 0:00:07
#    --------------------------- ------------ 34.1/50.1 MB 2.5 MB/s eta 0:00:07
#    --------------------------- ------------ 34.6/50.1 MB 2.5 MB/s eta 0:00:07
#    ---------------------------- ----------- 35.4/50.1 MB 2.6 MB/s eta 0:00:06
#    ---------------------------- ----------- 35.9/50.1 MB 2.6 MB/s eta 0:00:06
#    ----------------------------- ---------- 36.7/50.1 MB 2.6 MB/s eta 0:00:06
#    ----------------------------- ---------- 37.2/50.1 MB 2.6 MB/s eta 0:00:05
#    ------------------------------ --------- 38.0/50.1 MB 2.6 MB/s eta 0:00:05
#    ------------------------------ --------- 38.5/50.1 MB 2.6 MB/s eta 0:00:05
#    ------------------------------- -------- 39.3/50.1 MB 2.6 MB/s eta 0:00:05
#    ------------------------------- -------- 39.8/50.1 MB 2.6 MB/s eta 0:00:04
#    -------------------------------- ------- 40.6/50.1 MB 2.6 MB/s eta 0:00:04
#    --------------------------------- ------ 41.4/50.1 MB 2.6 MB/s eta 0:00:04
#    --------------------------------- ------ 42.2/50.1 MB 2.6 MB/s eta 0:00:03
#    ---------------------------------- ----- 43.0/50.1 MB 2.7 MB/s eta 0:00:03
#    ---------------------------------- ----- 43.8/50.1 MB 2.7 MB/s eta 0:00:03
#    ----------------------------------- ---- 44.6/50.1 MB 2.7 MB/s eta 0:00:03
#    ------------------------------------ --- 45.1/50.1 MB 2.7 MB/s eta 0:00:02
#    ------------------------------------ --- 45.6/50.1 MB 2.7 MB/s eta 0:00:02
#    ------------------------------------- -- 46.4/50.1 MB 2.7 MB/s eta 0:00:02
#    ------------------------------------- -- 46.9/50.1 MB 2.7 MB/s eta 0:00:02
#    -------------------------------------- - 47.7/50.1 MB 2.7 MB/s eta 0:00:01
#    -------------------------------------- - 48.2/50.1 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  49.0/50.1 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  49.5/50.1 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  50.1/50.1 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 50.1/50.1 MB 2.7 MB/s  0:00:18
# Downloading pyqt5_sip-12.18.0-cp311-cp311-win_amd64.whl (58 kB)
# Installing collected packages: PyQt5-Qt5, PyQt5-sip, pyqt5
#
#    ---------------------------------------- 0/3 [PyQt5-Qt5]
#    ---------------------------------------- 0/3 [PyQt5-Qt5]
#    ---------------------------------------- 0/3 [PyQt5-Qt5]
#    ---------------------------------------- 0/3 [PyQt5-Qt5]
#    ---------------------------------------- 0/3 [PyQt5-Qt5]
#    ---------------------------------------- 0/3 [PyQt5-Qt5]
#    ---------------------------------------- 0/3 [PyQt5-Qt5]
#    ---------------------------------------- 0/3 [PyQt5-Qt5]
#    ---------------------------------------- 0/3 [PyQt5-Qt5]
#    -------------------------- ------------- 2/3 [pyqt5]
#    -------------------------- ------------- 2/3 [pyqt5]
#    -------------------------- ------------- 2/3 [pyqt5]
#    -------------------------- ------------- 2/3 [pyqt5]
#    -------------------------- ------------- 2/3 [pyqt5]
#    -------------------------- ------------- 2/3 [pyqt5]
#    -------------------------- ------------- 2/3 [pyqt5]
#    -------------------------- ------------- 2/3 [pyqt5]
#    -------------------------- ------------- 2/3 [pyqt5]
#    -------------------------- ------------- 2/3 [pyqt5]
#    -------------------------- ------------- 2/3 [pyqt5]
#    -------------------------- ------------- 2/3 [pyqt5]
#    -------------------------- ------------- 2/3 [pyqt5]
#    ---------------------------------------- 3/3 [pyqt5]
#
# Successfully installed PyQt5-Qt5-5.15.2 PyQt5-sip-12.18.0 pyqt5-5.15.11
# Note: you may need to restart the kernel to use updated packages.

# %%
import PyQt5

# %%
doc
# Out:
# data science and ai has greate career ahead

# %%
for token in doc:
    print(token.text)
# Out:
# data
# science
# and
# ai
# has
# greate
# career
# ahead

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp("Apple is looking at buying U.K. startup for $1 billion")

for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
# Out:
# Apple Apple PROPN NNP nsubj Xxxxx True False
# is be AUX VBZ aux xx True True
# looking look VERB VBG ROOT xxxx True False
# at at ADP IN prep xx True True
# buying buy VERB VBG pcomp xxxx True False
# U.K. U.K. PROPN NNP nsubj X.X. False False
# startup startup VERB VBD ccomp xxxx True False
# for for ADP IN prep xxx True True
# $ $ SYM $ quantmod $ False False
# 1 1 NUM CD compound d False False
# billion billion NUM CD pobj xxxx True False

# %%
for token in doc:
    print(token.pos_)
# Out:
# PROPN
# AUX
# VERB
# ADP
# VERB
# PROPN
# VERB
# ADP
# SYM
# NUM
# NUM

# %%
for token in doc:
    print(token.text, token.pos_)
# Out:
# Apple PROPN
# is AUX
# looking VERB
# at ADP
# buying VERB
# U.K. PROPN
# startup VERB
# for ADP
# $ SYM
# 1 NUM
# billion NUM

# %%
for token in doc:
    print(token.text, token.pos_, token.lemma_)
# Out:
# Apple PROPN Apple
# is AUX be
# looking VERB look
# at ADP at
# buying VERB buy
# U.K. PROPN U.K.
# startup VERB startup
# for ADP for
# $ SYM $
# 1 NUM 1
# billion NUM billion

# %%
text = """There are broadly two types of extractive summarization tasks depending on what the summarization program focuses on. The first is generic summarization, which focuses on obtaining a generic summary or abstract of the collection (whether documents, or sets of images, or videos, news stories etc.). The second is query relevant summarization, sometimes called query-based summarization, which summarizes objects specific to a query. Summarization systems are able to create both query relevant text summaries and generic machine-generated summaries depending on what the user needs.
An example of a summarization problem is document summarization, which attempts to automatically produce an abstract from a given document. Sometimes one might be interested in generating a summary from a single source document, while others can use multiple source documents (for example, a cluster of articles on the same topic). This problem is called multi-document summarization. A related application is summarizing news articles. Imagine a system, which automatically pulls together news articles on a given topic (from the web), and concisely represents the latest news as a summary.
Image collection summarization is another application example of automatic summarization. It consists in selecting a representative set of images from a larger set of images.[4] A summary in this context is useful to show the most representative images of results in an image collection exploration system. Video summarization is a related domain, where the system automatically creates a trailer of a long video. This also has applications in consumer or personal videos, where one might want to skip the boring or repetitive actions. Similarly, in surveillance videos, one would want to extract important and suspicious activity, while ignoring all the boring and redundant frames captured """

# %%
text
# Out:
# 'There are broadly two types of extractive summarization tasks depending on what the summarization program focuses on. The first is generic summarization, which focuses on obtaining a generic summary or abstract of the collection (whether documents, or sets of images, or videos, news stories etc.). The second is query relevant summarization, sometimes called query-based summarization, which summarizes objects specific to a query. Summarization systems are able to create both query relevant text summaries and generic machine-generated summaries depending on what the user needs.\nAn example of a summarization problem is document summarization, which attempts to automatically produce an abstract from a given document. Sometimes one might be interested in generating a summary from a single source document, while others can use multiple source documents (for example, a cluster of articles on the same topic). This problem is called multi-document summarization. A related application is summarizing news articles. Imagine a system, which automatically pulls together news articles on a given topic (from the web), and concisely represents the latest news as a summary.\nImage collection summarization is another application example of automatic summarization. It consists in selecting a representative set of images from a larger set of images.[4] A summary in this context is useful to show the most representative images of results in an image collection exploration system. Video summarization is a related domain, where the system automatically creates a trailer of a long video. This also has applications in consumer or personal videos, where one might want to skip the boring or repetitive actions. Similarly, in surveillance videos, one would want to extract important and suspicious activity, while ignoring all the boring and redundant frames captured '

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation

# %%
stopwords = list(STOP_WORDS) 
stopwords
# Out:
# ['say',
#  'hers',
#  'yours',
#  'done',
#  'an',
#  'you',
#  'as',
#  'indeed',
#  'has',
#  'keep',
#  'moreover',
#  'among',
#  'hence',
#  'six',
#  "'s",
#  'which',
#  'one',
#  'thereafter',
#  'anyone',
#  'their',
#  'alone',
#  'is',
#  'no',
#  'almost',
#  'above',
#  'even',
#  'before',
#  'does',
#  'myself',
#  'go',
#  'twelve',
#  'back',
#  'our',
#  'whose',
#  'bottom',
#  'her',
#  'thereupon',
#  'first',
#  'whereby',
#  'all',
#  'both',
#  '‘ll',
#  'nobody',
#  'she',
#  'yourself',
#  'herself',
#  'last',
#  'were',
#  're',
#  'everyone',
#  'least',
#  'they',
#  '’s',
#  'without',
#  'them',
#  'but',
#  'via',
#  '’m',
#  'towards',
#  'then',
#  'across',
#  '‘m',
#  'might',
#  'made',
#  'same',
#  'since',
#  'around',
#  'for',
#  'except',
#  'his',
#  'whatever',
#  'me',
#  'wherever',
#  'put',
#  'did',
#  'about',
#  'either',
#  'though',
#  'beside',
#  'once',
#  "'m",
#  "'d",
#  'at',
#  'namely',
#  'move',
#  'such',
#  'be',
#  'more',
#  'over',
#  'whom',
#  'eleven',
#  'enough',
#  'will',
#  'part',
#  'in',
#  'who',
#  'my',
#  'whoever',
#  'seemed',
#  'anything',
#  'various',
#  'been',
#  'than',
#  'top',
#  'or',
#  'everywhere',
#  'nowhere',
#  'none',
#  'latterly',
#  'this',
#  'never',
#  'much',
#  'therein',
#  'every',
#  'its',
#  'any',
#  'many',
#  'get',
#  'why',
#  'anyhow',
#  'less',
#  'ours',
#  'else',
#  'call',
#  'herein',
#  'neither',
#  'third',
#  '’ve',
#  'otherwise',
#  'well',
#  'became',
#  'us',
#  'latter',
#  'was',
#  'not',
#  'under',
#  'besides',
#  'there',
#  'where',
#  '‘s',
#  'by',
#  'very',
#  'nothing',
#  'rather',
#  'five',
#  'are',
#  'too',
#  'that',
#  'somewhere',
#  'take',
#  'whereupon',
#  'from',
#  'often',
#  'up',
#  '’re',
#  'and',
#  'have',
#  'seems',
#  'together',
#  'still',
#  'a',
#  'hereafter',
#  'therefore',
#  'what',
#  'should',
#  'if',
#  'on',
#  'become',
#  'somehow',
#  'ten',
#  'eight',
#  'himself',
#  'four',
#  'it',
#  'used',
#  'now',
#  'sixty',
#  'unless',
#  'down',
#  'whither',
#  '’ll',
#  'whether',
#  'serious',
#  'although',
#  'again',
#  'regarding',
#  'within',
#  'already',
#  'during',
#  'nor',
#  'seem',
#  'full',
#  'side',
#  'two',
#  'with',
#  'some',
#  'wherein',
#  'amount',
#  'nine',
#  "n't",
#  'ca',
#  'when',
#  'am',
#  'another',
#  'these',
#  'name',
#  'empty',
#  'how',
#  'each',
#  'becomes',
#  'into',
#  'afterwards',
#  'nevertheless',
#  'using',
#  'hereby',
#  'whole',
#  'most',
#  'next',
#  'fifteen',
#  'per',
#  "'ll",
#  'others',
#  'while',
#  'the',
#  'front',
#  'so',
#  'former',
#  'whereafter',
#  'anywhere',
#  'your',
#  'between',
#  'thru',
#  'out',
#  'yourselves',
#  'several',
#  'onto',
#  'i',
#  'thence',
#  'sometime',
#  'beyond',
#  'themselves',
#  'see',
#  'after',
#  'everything',
#  'meanwhile',
#  'him',
#  'always',
#  'hereupon',
#  'would',
#  'thus',
#  'formerly',
#  'because',
#  'cannot',
#  'until',
#  'only',
#  'twenty',
#  'against',
#  '‘ve',
#  'through',
#  'mine',
#  'do',
#  'doing',
#  'throughout',
#  'ever',
#  'someone',
#  'give',
#  'quite',
#  'itself',
#  'due',
#  'seeming',
#  'perhaps',
#  'off',
#  'toward',
#  'below',
#  'make',
#  'other',
#  'please',
#  "'ve",
#  'forty',
#  'own',
#  'also',
#  'further',
#  'n‘t',
#  'becoming',
#  'could',
#  'whereas',
#  'we',
#  'yet',
#  'along',
#  'can',
#  'amongst',
#  'few',
#  'thereby',
#  'behind',
#  'must',
#  'had',
#  'mostly',
#  'show',
#  'beforehand',
#  'really',
#  'something',
#  'fifty',
#  'whenever',
#  'he',
#  "'re",
#  'being',
#  'however',
#  'whence',
#  'n’t',
#  'just',
#  'those',
#  'to',
#  'here',
#  'sometimes',
#  'ourselves',
#  'anyway',
#  'hundred',
#  'of',
#  '‘d',
#  'noone',
#  'may',
#  'elsewhere',
#  'three',
#  '’d',
#  'upon',
#  '‘re']

# %%
len(stopwords)
# Out:
# 326

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp(text)
doc
# Out:
# There are broadly two types of extractive summarization tasks depending on what the summarization program focuses on. The first is generic summarization, which focuses on obtaining a generic summary or abstract of the collection (whether documents, or sets of images, or videos, news stories etc.). The second is query relevant summarization, sometimes called query-based summarization, which summarizes objects specific to a query. Summarization systems are able to create both query relevant text summaries and generic machine-generated summaries depending on what the user needs.
# An example of a summarization problem is document summarization, which attempts to automatically produce an abstract from a given document. Sometimes one might be interested in generating a summary from a single source document, while others can use multiple source documents (for example, a cluster of articles on the same topic). This problem is called multi-document summarization. A related application is summarizing news articles. Imagine a system, which automatically pulls together news articles on a given topic (from the web), and concisely represents the latest news as a summary.
# Image collection summarization is another application example of automatic summarization. It consists in selecting a representative set of images from a larger set of images.[4] A summary in this context is useful to show the most representative images of results in an image collection exploration system. Video summarization is a related domain, where the system automatically creates a trailer of a long video. This also has applications in consumer or personal videos, where one might want to skip the boring or repetitive actions. Similarly, in surveillance videos, one would want to extract important and suspicious activity, while ignoring all the boring and redundant frames captured

# %%
# lets get the tokens from text
tokens = [token.text for token in doc]
print(tokens) 
#when we execute everythihg we created tokens from the text & not removed any of the stopwords & didnt cleaned the data
# Out:
# ['There', 'are', 'broadly', 'two', 'types', 'of', 'extractive', 'summarization', 'tasks', 'depending', 'on', 'what', 'the', 'summarization', 'program', 'focuses', 'on', '.', 'The', 'first', 'is', 'generic', 'summarization', ',', 'which', 'focuses', 'on', 'obtaining', 'a', 'generic', 'summary', 'or', 'abstract', 'of', 'the', 'collection', '(', 'whether', 'documents', ',', 'or', 'sets', 'of', 'images', ',', 'or', 'videos', ',', 'news', 'stories', 'etc', '.', ')', '.', 'The', 'second', 'is', 'query', 'relevant', 'summarization', ',', 'sometimes', 'called', 'query', '-', 'based', 'summarization', ',', 'which', 'summarizes', 'objects', 'specific', 'to', 'a', 'query', '.', 'Summarization', 'systems', 'are', 'able', 'to', 'create', 'both', 'query', 'relevant', 'text', 'summaries', 'and', 'generic', 'machine', '-', 'generated', 'summaries', 'depending', 'on', 'what', 'the', 'user', 'needs', '.', '\n', 'An', 'example', 'of', 'a', 'summarization', 'problem', 'is', 'document', 'summarization', ',', 'which', 'attempts', 'to', 'automatically', 'produce', 'an', 'abstract', 'from', 'a', 'given', 'document', '.', 'Sometimes', 'one', 'might', 'be', 'interested', 'in', 'generating', 'a', 'summary', 'from', 'a', 'single', 'source', 'document', ',', 'while', 'others', 'can', 'use', 'multiple', 'source', 'documents', '(', 'for', 'example', ',', 'a', 'cluster', 'of', 'articles', 'on', 'the', 'same', 'topic', ')', '.', 'This', 'problem', 'is', 'called', 'multi', '-', 'document', 'summarization', '.', 'A', 'related', 'application', 'is', 'summarizing', 'news', 'articles', '.', 'Imagine', 'a', 'system', ',', 'which', 'automatically', 'pulls', 'together', 'news', 'articles', 'on', 'a', 'given', 'topic', '(', 'from', 'the', 'web', ')', ',', 'and', 'concisely', 'represents', 'the', 'latest', 'news', 'as', 'a', 'summary', '.', '\n', 'Image', 'collection', 'summarization', 'is', 'another', 'application', 'example', 'of', 'automatic', 'summarization', '.', 'It', 'consists', 'in', 'selecting', 'a', 'representative', 'set', 'of', 'images', 'from', 'a', 'larger', 'set', 'of', 'images.[4', ']', 'A', 'summary', 'in', 'this', 'context', 'is', 'useful', 'to', 'show', 'the', 'most', 'representative', 'images', 'of', 'results', 'in', 'an', 'image', 'collection', 'exploration', 'system', '.', 'Video', 'summarization', 'is', 'a', 'related', 'domain', ',', 'where', 'the', 'system', 'automatically', 'creates', 'a', 'trailer', 'of', 'a', 'long', 'video', '.', 'This', 'also', 'has', 'applications', 'in', 'consumer', 'or', 'personal', 'videos', ',', 'where', 'one', 'might', 'want', 'to', 'skip', 'the', 'boring', 'or', 'repetitive', 'actions', '.', 'Similarly', ',', 'in', 'surveillance', 'videos', ',', 'one', 'would', 'want', 'to', 'extract', 'important', 'and', 'suspicious', 'activity', ',', 'while', 'ignoring', 'all', 'the', 'boring', 'and', 'redundant', 'frames', 'captured']

# %%
tokens
# Out:
# ['There',
#  'are',
#  'broadly',
#  'two',
#  'types',
#  'of',
#  'extractive',
#  'summarization',
#  'tasks',
#  'depending',
#  'on',
#  'what',
#  'the',
#  'summarization',
#  'program',
#  'focuses',
#  'on',
#  '.',
#  'The',
#  'first',
#  'is',
#  'generic',
#  'summarization',
#  ',',
#  'which',
#  'focuses',
#  'on',
#  'obtaining',
#  'a',
#  'generic',
#  'summary',
#  'or',
#  'abstract',
#  'of',
#  'the',
#  'collection',
#  '(',
#  'whether',
#  'documents',
#  ',',
#  'or',
#  'sets',
#  'of',
#  'images',
#  ',',
#  'or',
#  'videos',
#  ',',
#  'news',
#  'stories',
#  'etc',
#  '.',
#  ')',
#  '.',
#  'The',
#  'second',
#  'is',
#  'query',
#  'relevant',
#  'summarization',
#  ',',
#  'sometimes',
#  'called',
#  'query',
#  '-',
#  'based',
#  'summarization',
#  ',',
#  'which',
#  'summarizes',
#  'objects',
#  'specific',
#  'to',
#  'a',
#  'query',
#  '.',
#  'Summarization',
#  'systems',
#  'are',
#  'able',
#  'to',
#  'create',
#  'both',
#  'query',
#  'relevant',
#  'text',
#  'summaries',
#  'and',
#  'generic',
#  'machine',
#  '-',
#  'generated',
#  'summaries',
#  'depending',
#  'on',
#  'what',
#  'the',
#  'user',
#  'needs',
#  '.',
#  '\n',
#  'An',
#  'example',
#  'of',
#  'a',
#  'summarization',
#  'problem',
#  'is',
#  'document',
#  'summarization',
#  ',',
#  'which',
#  'attempts',
#  'to',
#  'automatically',
#  'produce',
#  'an',
#  'abstract',
#  'from',
#  'a',
#  'given',
#  'document',
#  '.',
#  'Sometimes',
#  'one',
#  'might',
#  'be',
#  'interested',
#  'in',
#  'generating',
#  'a',
#  'summary',
#  'from',
#  'a',
#  'single',
#  'source',
#  'document',
#  ',',
#  'while',
#  'others',
#  'can',
#  'use',
#  'multiple',
#  'source',
#  'documents',
#  '(',
#  'for',
#  'example',
#  ',',
#  'a',
#  'cluster',
#  'of',
#  'articles',
#  'on',
#  'the',
#  'same',
#  'topic',
#  ')',
#  '.',
#  'This',
#  'problem',
#  'is',
#  'called',
#  'multi',
#  '-',
#  'document',
#  'summarization',
#  '.',
#  'A',
#  'related',
#  'application',
#  'is',
#  'summarizing',
#  'news',
#  'articles',
#  '.',
#  'Imagine',
#  'a',
#  'system',
#  ',',
#  'which',
#  'automatically',
#  'pulls',
#  'together',
#  'news',
#  'articles',
#  'on',
#  'a',
#  'given',
#  'topic',
#  '(',
#  'from',
#  'the',
#  'web',
#  ')',
#  ',',
#  'and',
#  'concisely',
#  'represents',
#  'the',
#  'latest',
#  'news',
#  'as',
#  'a',
#  'summary',
#  '.',
#  '\n',
#  'Image',
#  'collection',
#  'summarization',
#  'is',
#  'another',
#  'application',
#  'example',
#  'of',
#  'automatic',
#  'summarization',
#  '.',
#  'It',
#  'consists',
#  'in',
#  'selecting',
#  'a',
#  'representative',
#  'set',
#  'of',
#  'images',
#  'from',
#  'a',
#  'larger',
#  'set',
#  'of',
#  'images.[4',
#  ']',
#  'A',
#  'summary',
#  'in',
#  'this',
#  'context',
#  'is',
#  'useful',
#  'to',
#  'show',
#  'the',
#  'most',
#  'representative',
#  'images',
#  'of',
#  'results',
#  'in',
#  'an',
#  'image',
#  'collection',
#  'exploration',
#  'system',
#  '.',
#  'Video',
#  'summarization',
#  'is',
#  'a',
#  'related',
#  'domain',
#  ',',
#  'where',
#  'the',
#  'system',
#  'automatically',
#  'creates',
#  'a',
#  'trailer',
#  'of',
#  'a',
#  'long',
#  'video',
#  '.',
#  'This',
#  'also',
#  'has',
#  'applications',
#  'in',
#  'consumer',
#  'or',
#  'personal',
#  'videos',
#  ',',
#  'where',
#  'one',
#  'might',
#  'want',
#  'to',
#  'skip',
#  'the',
#  'boring',
#  'or',
#  'repetitive',
#  'actions',
#  '.',
#  'Similarly',
#  ',',
#  'in',
#  'surveillance',
#  'videos',
#  ',',
#  'one',
#  'would',
#  'want',
#  'to',
#  'extract',
#  'important',
#  'and',
#  'suspicious',
#  'activity',
#  ',',
#  'while',
#  'ignoring',
#  'all',
#  'the',
#  'boring',
#  'and',
#  'redundant',
#  'frames',
#  'captured']

# %%
len(tokens)
# Out:
# 322

# %%
punctuation # also called as noisy characters
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
#we have to calcualte the freaquency of each and every word, how many time word is repetation in text 

word_frequencies = {}

for word in doc:
    if word.text.lower() not in stopwords:
        if word.text.lower() not in punctuation:
            if word.text not in word_frequencies.keys():
                word_frequencies[word.text] = 1
            else:
                word_frequencies[word.text] += 1

# %%
word_frequencies
#print(word_frequencies)
# Out:
# {'broadly': 1,
#  'types': 1,
#  'extractive': 1,
#  'summarization': 11,
#  'tasks': 1,
#  'depending': 2,
#  'program': 1,
#  'focuses': 2,
#  'generic': 3,
#  'obtaining': 1,
#  'summary': 4,
#  'abstract': 2,
#  'collection': 3,
#  'documents': 2,
#  'sets': 1,
#  'images': 3,
#  'videos': 3,
#  'news': 4,
#  'stories': 1,
#  'etc': 1,
#  'second': 1,
#  'query': 4,
#  'relevant': 2,
#  'called': 2,
#  'based': 1,
#  'summarizes': 1,
#  'objects': 1,
#  'specific': 1,
#  'Summarization': 1,
#  'systems': 1,
#  'able': 1,
#  'create': 1,
#  'text': 1,
#  'summaries': 2,
#  'machine': 1,
#  'generated': 1,
#  'user': 1,
#  'needs': 1,
#  '\n': 2,
#  'example': 3,
#  'problem': 2,
#  'document': 4,
#  'attempts': 1,
#  'automatically': 3,
#  'produce': 1,
#  'given': 2,
#  'interested': 1,
#  'generating': 1,
#  'single': 1,
#  'source': 2,
#  'use': 1,
#  'multiple': 1,
#  'cluster': 1,
#  'articles': 3,
#  'topic': 2,
#  'multi': 1,
#  'related': 2,
#  'application': 2,
#  'summarizing': 1,
#  'Imagine': 1,
#  'system': 3,
#  'pulls': 1,
#  'web': 1,
#  'concisely': 1,
#  'represents': 1,
#  'latest': 1,
#  'Image': 1,
#  'automatic': 1,
#  'consists': 1,
#  'selecting': 1,
#  'representative': 2,
#  'set': 2,
#  'larger': 1,
#  'images.[4': 1,
#  'context': 1,
#  'useful': 1,
#  'results': 1,
#  'image': 1,
#  'exploration': 1,
#  'Video': 1,
#  'domain': 1,
#  'creates': 1,
#  'trailer': 1,
#  'long': 1,
#  'video': 1,
#  'applications': 1,
#  'consumer': 1,
#  'personal': 1,
#  'want': 2,
#  'skip': 1,
#  'boring': 2,
#  'repetitive': 1,
#  'actions': 1,
#  'Similarly': 1,
#  'surveillance': 1,
#  'extract': 1,
#  'important': 1,
#  'suspicious': 1,
#  'activity': 1,
#  'ignoring': 1,
#  'redundant': 1,
#  'frames': 1,
#  'captured': 1}

# %%
len(word_frequencies)
# Out:
# 103

# %%
word_frequencies
# Out:
# {'broadly': 1,
#  'types': 1,
#  'extractive': 1,
#  'summarization': 11,
#  'tasks': 1,
#  'depending': 2,
#  'program': 1,
#  'focuses': 2,
#  'generic': 3,
#  'obtaining': 1,
#  'summary': 4,
#  'abstract': 2,
#  'collection': 3,
#  'documents': 2,
#  'sets': 1,
#  'images': 3,
#  'videos': 3,
#  'news': 4,
#  'stories': 1,
#  'etc': 1,
#  'second': 1,
#  'query': 4,
#  'relevant': 2,
#  'called': 2,
#  'based': 1,
#  'summarizes': 1,
#  'objects': 1,
#  'specific': 1,
#  'Summarization': 1,
#  'systems': 1,
#  'able': 1,
#  'create': 1,
#  'text': 1,
#  'summaries': 2,
#  'machine': 1,
#  'generated': 1,
#  'user': 1,
#  'needs': 1,
#  '\n': 2,
#  'example': 3,
#  'problem': 2,
#  'document': 4,
#  'attempts': 1,
#  'automatically': 3,
#  'produce': 1,
#  'given': 2,
#  'interested': 1,
#  'generating': 1,
#  'single': 1,
#  'source': 2,
#  'use': 1,
#  'multiple': 1,
#  'cluster': 1,
#  'articles': 3,
#  'topic': 2,
#  'multi': 1,
#  'related': 2,
#  'application': 2,
#  'summarizing': 1,
#  'Imagine': 1,
#  'system': 3,
#  'pulls': 1,
#  'web': 1,
#  'concisely': 1,
#  'represents': 1,
#  'latest': 1,
#  'Image': 1,
#  'automatic': 1,
#  'consists': 1,
#  'selecting': 1,
#  'representative': 2,
#  'set': 2,
#  'larger': 1,
#  'images.[4': 1,
#  'context': 1,
#  'useful': 1,
#  'results': 1,
#  'image': 1,
#  'exploration': 1,
#  'Video': 1,
#  'domain': 1,
#  'creates': 1,
#  'trailer': 1,
#  'long': 1,
#  'video': 1,
#  'applications': 1,
#  'consumer': 1,
#  'personal': 1,
#  'want': 2,
#  'skip': 1,
#  'boring': 2,
#  'repetitive': 1,
#  'actions': 1,
#  'Similarly': 1,
#  'surveillance': 1,
#  'extract': 1,
#  'important': 1,
#  'suspicious': 1,
#  'activity': 1,
#  'ignoring': 1,
#  'redundant': 1,
#  'frames': 1,
#  'captured': 1}

# %%
max_frequency = max(word_frequencies.values())
max_frequency
# Out:
# 11

# %%
#to get normalized/weighted frequencies you should devide all frequencies with 11
for word in word_frequencies.keys():
    word_frequencies[word] = word_frequencies[word]/max_frequency

# %%
word_frequencies
# Out:
# {'broadly': 0.09090909090909091,
#  'types': 0.09090909090909091,
#  'extractive': 0.09090909090909091,
#  'summarization': 1.0,
#  'tasks': 0.09090909090909091,
#  'depending': 0.18181818181818182,
#  'program': 0.09090909090909091,
#  'focuses': 0.18181818181818182,
#  'generic': 0.2727272727272727,
#  'obtaining': 0.09090909090909091,
#  'summary': 0.36363636363636365,
#  'abstract': 0.18181818181818182,
#  'collection': 0.2727272727272727,
#  'documents': 0.18181818181818182,
#  'sets': 0.09090909090909091,
#  'images': 0.2727272727272727,
#  'videos': 0.2727272727272727,
#  'news': 0.36363636363636365,
#  'stories': 0.09090909090909091,
#  'etc': 0.09090909090909091,
#  'second': 0.09090909090909091,
#  'query': 0.36363636363636365,
#  'relevant': 0.18181818181818182,
#  'called': 0.18181818181818182,
#  'based': 0.09090909090909091,
#  'summarizes': 0.09090909090909091,
#  'objects': 0.09090909090909091,
#  'specific': 0.09090909090909091,
#  'Summarization': 0.09090909090909091,
#  'systems': 0.09090909090909091,
#  'able': 0.09090909090909091,
#  'create': 0.09090909090909091,
#  'text': 0.09090909090909091,
#  'summaries': 0.18181818181818182,
#  'machine': 0.09090909090909091,
#  'generated': 0.09090909090909091,
#  'user': 0.09090909090909091,
#  'needs': 0.09090909090909091,
#  '\n': 0.18181818181818182,
#  'example': 0.2727272727272727,
#  'problem': 0.18181818181818182,
#  'document': 0.36363636363636365,
#  'attempts': 0.09090909090909091,
#  'automatically': 0.2727272727272727,
#  'produce': 0.09090909090909091,
#  'given': 0.18181818181818182,
#  'interested': 0.09090909090909091,
#  'generating': 0.09090909090909091,
#  'single': 0.09090909090909091,
#  'source': 0.18181818181818182,
#  'use': 0.09090909090909091,
#  'multiple': 0.09090909090909091,
#  'cluster': 0.09090909090909091,
#  'articles': 0.2727272727272727,
#  'topic': 0.18181818181818182,
#  'multi': 0.09090909090909091,
#  'related': 0.18181818181818182,
#  'application': 0.18181818181818182,
#  'summarizing': 0.09090909090909091,
#  'Imagine': 0.09090909090909091,
#  'system': 0.2727272727272727,
#  'pulls': 0.09090909090909091,
#  'web': 0.09090909090909091,
#  'concisely': 0.09090909090909091,
#  'represents': 0.09090909090909091,
#  'latest': 0.09090909090909091,
#  'Image': 0.09090909090909091,
#  'automatic': 0.09090909090909091,
#  'consists': 0.09090909090909091,
#  'selecting': 0.09090909090909091,
#  'representative': 0.18181818181818182,
#  'set': 0.18181818181818182,
#  'larger': 0.09090909090909091,
#  'images.[4': 0.09090909090909091,
#  'context': 0.09090909090909091,
#  'useful': 0.09090909090909091,
#  'results': 0.09090909090909091,
#  'image': 0.09090909090909091,
#  'exploration': 0.09090909090909091,
#  'Video': 0.09090909090909091,
#  'domain': 0.09090909090909091,
#  'creates': 0.09090909090909091,
#  'trailer': 0.09090909090909091,
#  'long': 0.09090909090909091,
#  'video': 0.09090909090909091,
#  'applications': 0.09090909090909091,
#  'consumer': 0.09090909090909091,
#  'personal': 0.09090909090909091,
#  'want': 0.18181818181818182,
#  'skip': 0.09090909090909091,
#  'boring': 0.18181818181818182,
#  'repetitive': 0.09090909090909091,
#  'actions': 0.09090909090909091,
#  'Similarly': 0.09090909090909091,
#  'surveillance': 0.09090909090909091,
#  'extract': 0.09090909090909091,
#  'important': 0.09090909090909091,
#  'suspicious': 0.09090909090909091,
#  'activity': 0.09090909090909091,
#  'ignoring': 0.09090909090909091,
#  'redundant': 0.09090909090909091,
#  'frames': 0.09090909090909091,
#  'captured': 0.09090909090909091}

# %%
sentence_tokens = [sent for sent in doc.sents]
sentence_tokens
# Out:
# [There are broadly two types of extractive summarization tasks depending on what the summarization program focuses on.,
#  The first is generic summarization, which focuses on obtaining a generic summary or abstract of the collection (whether documents, or sets of images, or videos, news stories etc.).,
#  The second is query relevant summarization, sometimes called query-based summarization, which summarizes objects specific to a query.,
#  Summarization systems are able to create both query relevant text summaries and generic machine-generated summaries depending on what the user needs.,
#  An example of a summarization problem is document summarization, which attempts to automatically produce an abstract from a given document.,
#  Sometimes one might be interested in generating a summary from a single source document, while others can use multiple source documents (for example, a cluster of articles on the same topic).,
#  This problem is called multi-document summarization.,
#  A related application is summarizing news articles.,
#  Imagine a system, which automatically pulls together news articles on a given topic (from the web), and concisely represents the latest news as a summary.,
#  Image collection summarization is another application example of automatic summarization.,
#  It consists in selecting a representative set of images from a larger set of images.[4],
#  A summary in this context is useful to show the most representative images of results in an image collection exploration system.,
#  Video summarization is a related domain, where the system automatically creates a trailer of a long video.,
#  This also has applications in consumer or personal videos, where one might want to skip the boring or repetitive actions.,
#  Similarly, in surveillance videos, one would want to extract important and suspicious activity, while ignoring all the boring and redundant frames captured]

# %%
len(sentence_tokens)
# Out:
# 15

# %%
# we are going to calculate the sentence score, to calculate the sentence score 
sentence_scores = {}

for sent in sentence_tokens:
    for word in sent:
        if word.text.lower() in word_frequencies.keys():
            if sent not in sentence_scores.keys():
                sentence_scores[sent] = word_frequencies[word.text.lower()]
            else:
                sentence_scores[sent] += word_frequencies[word.text.lower()]

# %%
sentence_tokens
# Out:
# [There are broadly two types of extractive summarization tasks depending on what the summarization program focuses on.,
#  The first is generic summarization, which focuses on obtaining a generic summary or abstract of the collection (whether documents, or sets of images, or videos, news stories etc.).,
#  The second is query relevant summarization, sometimes called query-based summarization, which summarizes objects specific to a query.,
#  Summarization systems are able to create both query relevant text summaries and generic machine-generated summaries depending on what the user needs.,
#  An example of a summarization problem is document summarization, which attempts to automatically produce an abstract from a given document.,
#  Sometimes one might be interested in generating a summary from a single source document, while others can use multiple source documents (for example, a cluster of articles on the same topic).,
#  This problem is called multi-document summarization.,
#  A related application is summarizing news articles.,
#  Imagine a system, which automatically pulls together news articles on a given topic (from the web), and concisely represents the latest news as a summary.,
#  Image collection summarization is another application example of automatic summarization.,
#  It consists in selecting a representative set of images from a larger set of images.[4],
#  A summary in this context is useful to show the most representative images of results in an image collection exploration system.,
#  Video summarization is a related domain, where the system automatically creates a trailer of a long video.,
#  This also has applications in consumer or personal videos, where one might want to skip the boring or repetitive actions.,
#  Similarly, in surveillance videos, one would want to extract important and suspicious activity, while ignoring all the boring and redundant frames captured]

# %%
from heapq import nlargest

# %%
select_length = int(len(sentence_tokens)*0.4)
select_length
# Out:
# 6

# %%
#we have to select maximum 4 sentences out of all sentences 
summary = nlargest(select_length,sentence_scores, key = sentence_scores.get)

# %%
summary
# Out:
# [An example of a summarization problem is document summarization, which attempts to automatically produce an abstract from a given document.,
#  The first is generic summarization, which focuses on obtaining a generic summary or abstract of the collection (whether documents, or sets of images, or videos, news stories etc.).,
#  The second is query relevant summarization, sometimes called query-based summarization, which summarizes objects specific to a query.,
#  Summarization systems are able to create both query relevant text summaries and generic machine-generated summaries depending on what the user needs.,
#  Image collection summarization is another application example of automatic summarization.,
#  Imagine a system, which automatically pulls together news articles on a given topic (from the web), and concisely represents the latest news as a summary.]

# %%
sentence_scores
# Out:
# {There are broadly two types of extractive summarization tasks depending on what the summarization program focuses on.: 2.818181818181818,
#  The first is generic summarization, which focuses on obtaining a generic summary or abstract of the collection (whether documents, or sets of images, or videos, news stories etc.).: 3.9999999999999987,
#  The second is query relevant summarization, sometimes called query-based summarization, which summarizes objects specific to a query.: 3.909090909090909,
#  Summarization systems are able to create both query relevant text summaries and generic machine-generated summaries depending on what the user needs.: 3.2727272727272716,
#  An example of a summarization problem is document summarization, which attempts to automatically produce an abstract from a given document.: 3.9999999999999996,
#  Sometimes one might be interested in generating a summary from a single source document, while others can use multiple source documents (for example, a cluster of articles on the same topic).: 2.545454545454545,
#  This problem is called multi-document summarization.: 1.8181818181818183,
#  A related application is summarizing news articles.: 1.0909090909090908,
#  Imagine a system, which automatically pulls together news articles on a given topic (from the web), and concisely represents the latest news as a summary.: 2.9090909090909087,
#  Image collection summarization is another application example of automatic summarization.: 2.909090909090909,
#  It consists in selecting a representative set of images from a larger set of images.[4]: 1.1818181818181817,
#  A summary in this context is useful to show the most representative images of results in an image collection exploration system.: 1.818181818181818,
#  Video summarization is a related domain, where the system automatically creates a trailer of a long video.: 2.2727272727272725,
#  This also has applications in consumer or personal videos, where one might want to skip the boring or repetitive actions.: 1.1818181818181817,
#  Similarly, in surveillance videos, one would want to extract important and suspicious activity, while ignoring all the boring and redundant frames captured: 1.4545454545454544}

# %%
# if i need to combine these top 3 sentencs then 

final_summary = [word.text for word in summary]

# %%
final_summary
# Out:
# ['An example of a summarization problem is document summarization, which attempts to automatically produce an abstract from a given document.',
#  'The first is generic summarization, which focuses on obtaining a generic summary or abstract of the collection (whether documents, or sets of images, or videos, news stories etc.).',
#  'The second is query relevant summarization, sometimes called query-based summarization, which summarizes objects specific to a query.',
#  'Summarization systems are able to create both query relevant text summaries and generic machine-generated summaries depending on what the user needs.\n',
#  'Image collection summarization is another application example of automatic summarization.',
#  'Imagine a system, which automatically pulls together news articles on a given topic (from the web), and concisely represents the latest news as a summary.\n']

# %%
print(final_summary)
# Out:
# ['An example of a summarization problem is document summarization, which attempts to automatically produce an abstract from a given document.', 'The first is generic summarization, which focuses on obtaining a generic summary or abstract of the collection (whether documents, or sets of images, or videos, news stories etc.).', 'The second is query relevant summarization, sometimes called query-based summarization, which summarizes objects specific to a query.', 'Summarization systems are able to create both query relevant text summaries and generic machine-generated summaries depending on what the user needs.\n', 'Image collection summarization is another application example of automatic summarization.', 'Imagine a system, which automatically pulls together news articles on a given topic (from the web), and concisely represents the latest news as a summary.\n']

# %%
print(summary)
# Out:
# [An example of a summarization problem is document summarization, which attempts to automatically produce an abstract from a given document., The first is generic summarization, which focuses on obtaining a generic summary or abstract of the collection (whether documents, or sets of images, or videos, news stories etc.)., The second is query relevant summarization, sometimes called query-based summarization, which summarizes objects specific to a query., Summarization systems are able to create both query relevant text summaries and generic machine-generated summaries depending on what the user needs.
# , Image collection summarization is another application example of automatic summarization., Imagine a system, which automatically pulls together news articles on a given topic (from the web), and concisely represents the latest news as a summary.
# ]
