# %%
x =input()
x
# Out:
#  5
# '5'

# %%
x= input()
y= input()

z= x+y

print(z)
# Out:
#  6
#  5
# 65

# %%
print(type(x))
print(type(y))
# Out:
# <class 'str'>
# <class 'str'>

# %%
x1= input('enter the 1st number')
x2= input('enter the 2nd number')

z1 =x1+x2
print(z1)
# Out:
# enter the 1st number 6
# enter the 2nd number 2
# 62

# %%
print(type(x1))
# Out:
# <class 'str'>

# %%
x2=input('user name')
y2=input(' password')
z2=x2+y2
print(z2)
# Out:
# user name likhith
#  password 789
# likhith789

# %%
st= input ('enter a string')
print(st)
# Out:
# enter a string hi
# hi

# %%
st =input('enter  a string')[1]
print(st)
# Out:
# enter  a string likhith
# i

# %%
st =input('enter  a string')[6]
print(st)
# Out:
# enter  a string likhith
# h

# %%
st =input('enter  a string')[1:7
]
print(st)
# Out:
# enter  a string youtube
# outube

# %%
st =input('enter  a string')[2:6]
print(st)
# Out:
# enter  a string youtube
# utub

# %%
result = int (input('enter an expe'))
             print(result)
# Out:
#   Cell In[19], line 2
#     print(result)
#     ^
# IndentationError: unexpected indent

# %%
result = eval(input('enter an expr'))
print(result)
# Out:
# enter an expr 5+6
# 11
