# %% [markdown]
# 23-10-2025

# %% [markdown]
# list

# %%
l =[100,20,30,40,'jan','feb',10]
l
# Out:
# [100, 20, 30, 40, 'jan', 'feb', 10]

# %%
print(type(l))
# Out:
# <class 'list'>

# %%
l.append(10)

# %%
l
# Out:
# [100, 20, 30, 40, 'jan', 'feb', 10, 10, 10]

# %%
len(l)
# Out:
# 9

# %%
l.append(20,30)
l
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 l.append(20,30)
#       2 l
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
l
# Out:
# [100, 20, 30, 40, 'jan', 'feb', 10, 10, 10]

# %%
# Out:
# (100, 20, 30, 40, 'jan', 'feb', 10)

# %%
l.insert(25,2)

# %%
l
# Out:
# (100, 20, 30, 40, 'jan', 'feb', 10)

# %%
l1=l.copy()
l1
# Out:
# [100, 20, 30, 40, 'jan', 'feb', 10, 10, 10]

# %%
print(l)
print(l1)
# Out:
# [100, 20, 30, 40, 'jan', 'feb', 10, 10, 10]
# [100, 20, 30, 40, 'jan', 'feb', 10, 10, 10]

# %%
id(l)==id(l1)
# Out:
# False

# %%
id(l)!=id(l1)
# Out:
# True

# %%
l2=[]

# %%
l2.append(6)
l2.append('nit')
l2.append(True)
l2.append(1+2j)
l2.append(16.6)

# %%
l2
# Out:
# [6, 'nit', True, (1+2j), 16.6]

# %%
print(l1)
print(l2)
# Out:
# [100, 20, 30, 40, 'jan', 'feb', 10, 10, 10]
# [6, 'nit', True, (1+2j), 16.6]

# %%
l
# Out:
# [100, 20, 30, 40, 'jan', 'feb', 10, 10]

# %%
l.index(100)
# Out:
# 0

# %%
l.index(30)
# Out:
# 2

# %%
l2
# Out:
# [6, 'nit', True, (1+2j), 16.6]

# %%
l2[1]
# Out:
# 'nit'

# %%
l2[1][0]
# Out:
# 'n'

# %%
print(l2[1])
# Out:
# nit

# %%
print(l2[1][0])
print(l2[1][1])
print(l2[1][2])
# Out:
# n
# i
# t

# %%
l
# Out:
# [100, 20, 30, 40, 'jan', 'feb', 10, 10]

# %%
l.insert(2,15)
l
# Out:
# [100, 20, 15, 15, 30, 40, 'jan', 'feb', 10, 10]

# %%
l.pop()
# Out:
# 10

# %%
l.remove((10))

# %%
l
# Out:
# [100, 20, 15, 15, 30, 40, 'jan', 'feb']

# %%
l.remove(15)

# %%
l
# Out:
# [100, 20, 15, 30, 40, 'jan', 'feb']

# %%
l
# Out:
# [100, 20, 15, 30, 40, 'jan', 'feb']

# %%
l.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 l.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
l
# Out:
# [15, 20, 30, 40, 100, 'jan', 'feb']

# %%
l.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 l.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
l
# Out:
# (100, 20, 30, 40, 'jan', 'feb', 10)

# %%
l1 =[10,40,60,50,12,63]

# %%
l1
# Out:
# [10, 40, 60, 50, 12, 63]

# %%
l1.sort()

# %%
l1
# Out:
# [10, 12, 40, 50, 60, 63]

# %%
l2 =['m','r','t','a','f']

# %%
l2
# Out:
# ['m', 'r', 't', 'a', 'f']

# %%
l2.sort()

# %%
l2
# Out:
# ['a', 'f', 'm', 'r', 't']

# %%
l1
# Out:
# [10, 12, 40, 50, 60, 63]

# %%
l1.reverse()

# %% [markdown]
# l1

# %%
l1
# Out:
# [63, 60, 50, 40, 12, 10]

# %%
l
# Out:
# [15, 20, 30, 40, 100, 'jan', 'feb']

# %%
l.reverse()

# %%
l
# Out:
# ['feb', 'jan', 100, 40, 30, 20, 15]

# %%
l[6]
# Out:
# 15

# %%
print(l[1][0])
print(l[1][1])
print(l[1][2])
# Out:
# j
# a
# n

# %%
l[:2]
# Out:
# ['feb', 'jan']

# %%
l[:6]
# Out:
# ['feb', 'jan', 100, 40, 30, 20]

# %%
l
# Out:
# ['feb', 'jan', 100, 40, 30, 20, 15]

# %%
l
# Out:
# ['feb', 'jan', 100, 40, 30, 20, 15]

# %%
l3 = [1,2,3,4,5]

# %%
l3
# Out:
# [1, 2, 3, 4, 5]

# %%
all(l3)
# Out:
# True

# %%
any(l3)
# Out:
# True

# %%
all(l3)
# Out:
# True

# %%
l4=(0,1,2,2,3,4)
l4
# Out:
# (0, 1, 2, 2, 3, 4)

# %%
all(l4)
# Out:
# False

# %%
any(l4)
# Out:
# True

# %% [markdown]
# # Loop through a list

# %%
list1=['one','two','three','four','five']
list1
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
for i in list1: 
   print(i)
# Out:
# one
# two
# three
# four
# five

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
for i in enumerate(list1):
    print(i)
# Out:
# (0, 'one')
# (1, 'two')
# (2, 'three')
# (3, 'four')
# (4, 'five')
