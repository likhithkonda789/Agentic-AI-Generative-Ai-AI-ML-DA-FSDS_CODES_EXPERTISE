# %% [markdown]
# # 15th

# %%
false = 56

# %%
false
# Out:
# 56

# %%
False = 10
# Out:
#   Cell In[3], line 1
#     False = 10
#     ^
# SyntaxError: cannot assign to False

# %%
true =20

# %%
true
# Out:
# 20

# %%
True =20
# Out:
#   Cell In[8], line 1
#     True =20
#     ^
# SyntaxError: cannot assign to True

# %% [markdown]
# # python data types

# %% [raw]
# .int
# .float
# .bool
# .string
# .complex

# %% [markdown]
# # int, float

# %%
i=5
i
# Out:
# 5

# %%
type (i)
# Out:
# int

# %%
i
# Out:
# 5

# %%
f=20.2

# %%
f
# Out:
# 20.2

# %%
type (f)
# Out:
# float

# %%
i
f
# Out:
# 20.2

# %%
print(i)
print(f)
# Out:
# 5
# 20.2

# %%
i+f
# Out:
# 25.2

# %%
i-f
# Out:
# -15.2

# %%
i*f
# Out:
# 101.0

# %%
i/f
# Out:
# 0.24752475247524752

# %% [markdown]
# # bool

# %%
true
# Out:
# 20

# %%
false
# Out:
# 56

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True+True
# Out:
# 2

# %%
True-True
# Out:
# 0

# %%
False+False
# Out:
# 0

# %%
False-False
# Out:
# 0

# %%
True+False
# Out:
# 1

# %%
True-False
# Out:
# 1

# %%
True*False
# Out:
# 0

# %%
True/False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %%
True/True
# Out:
# 1.0

# %%
False/False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 False/False
#
# ZeroDivisionError: division by zero

# %%
True//True
# Out:
# 1

# %% [markdown]
# # string

# %%
s=hello
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 s=hello
#       2 s
#
# NameError: name 'hello' is not defined

# %%
s='hello'
s
# Out:
# 'hello'

# %%
s1="hello"
s1
# Out:
# 'hello'

# %%
s2='''hello'''

# %%
s2
# Out:
# 'hello'

# %%
s3= '''hello
                    team'''
s3
# Out:
# 'hello\n                    team'

# %% [markdown]
# # complex

# %%
c=10+20j
c
# Out:
# (10+20j)

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0

# %%
c=10+20j
d=20+30j

# %%
c+d
# Out:
# (30+50j)

# %%
c-d
# Out:
# (-10-10j)

# %%
c*d
# Out:
# (-400+700j)

# %%
c/d
# Out:
# (0.6153846153846154+0.0769230769230769j)

# %% [raw]
# python  data type complete

# %% [markdown]
# # 16th

# %% [markdown]
# # Type casting==Convert one Datatype to other Datatype

# %%
# all other data type to int

# %%
int (2.4)
# Out:
# 2

# %%
int (2.4, 3.3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 int (2.4, 3.3)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
int (True )
# Out:
# 1

# %%
int (False)
# Out:
# 0

# %%
int ('10')
# Out:
# 10

# %%
int('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 int('ten')
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %%
int (1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 int (1+2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
# all other data type to float

# %%
float (10)
# Out:
# 10.0

# %%
float (10,20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 float (10,20)
#
# TypeError: float expected at most 1 argument, got 2

# %%
float (1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 float (1+2j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float('10')
# Out:
# 10.0

# %%
float('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 float('ten')
#
# ValueError: could not convert string to float: 'ten'

# %%
# all other data type to sting

# %%
str(7)
# Out:
# '7'

# %%
str(6.67)
# Out:
# '6.67'

# %%
str(1+2j)
# Out:
# '(1+2j)'

# %%
str(True)
# Out:
# 'True'

# %%
str()
# Out:
# ''

# %%
# all other data type to bool

# %%
bool(100)
# Out:
# True

# %%
bool (10.10)
# Out:
# True

# %%
bool()
# Out:
# False

# %%
bool('10')
# Out:
# True

# %%
bool('ten')
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(1+2j)
# Out:
# True

# %%
# all other data type to complex

# %%
complex (10)
# Out:
# (10+0j)

# %%
complex (20)
# Out:
# (20+0j)

# %%
complex(10,20)
# Out:
# (10+20j)

# %%
complex (10,20,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 complex (10,20,30)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex ( 10.20)
# Out:
# (10.2+0j)

# %%
complex (10.2,20.2)
# Out:
# (10.2+20.2j)

# %%
complex( True)
# Out:
# (1+0j)

# %%
complex (False)
# Out:
# 0j

# %%
complex ('19')
# Out:
# (19+0j)

# %%
complex ('18','1')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 complex ('18','1')
#
# TypeError: complex() can't take second arg if first is a string

# %%
complex (True,False)
# Out:
# (1+0j)
