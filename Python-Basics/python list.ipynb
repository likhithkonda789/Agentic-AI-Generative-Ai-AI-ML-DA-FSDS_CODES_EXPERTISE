# %%
#22-10-2025

# %% [markdown]
# # list
# # tuple
# # set
# # dict
# # range

# %% [markdown]
# # List

# %%
l=[]

# %%
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %%
l.append()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 l.append()
#
# TypeError: list.append() takes exactly one argument (0 given)

# %%
l.append(16)
l
# Out:
# [16, 16]

# %%
l
# Out:
# [16, 16]

# %%
l.append(10)
l.append(20)
l.append(30)

# %%
l
# Out:
# [16, 16, 10, 20, 30]

# %%
l1=[10,20,30.5,'ten',True,1+2j]
l1
# Out:
# [10, 20, 30.5, 'ten', True, (1+2j)]

# %%
print(l)
print(l1)
# Out:
# [16, 16, 10, 20, 30]
# [10, 20, 30.5, 'ten', True, (1+2j)]

# %%
print(len(l))
print(len(l1))
# Out:
# 5
# 6

# %%
print(id(l))
print(id(l1))
# Out:
# 2218618888832
# 2218632988224

# %%
l2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 l2
#
# NameError: name 'l2' is not defined

# %%
l2=l1.copy()
l2
# Out:
# [10, 20, 30.5, 'ten', True, (1+2j)]

# %%
l2==l1
# Out:
# True

# %%
l==l2
# Out:
# False

# %%
print(l)
print(l1)
print(l2)
# Out:
# [16, 16, 10, 20, 30]
# [10, 20, 30.5, 'ten', True, (1+2j)]
# [10, 20, 30.5, 'ten', True, (1+2j)]

# %%
l!=l1
# Out:
# True

# %%
l!=l2
# Out:
# True

# %%
l1!=l2
# Out:
# False

# %%
l[:]
# Out:
# [16, 16, 10, 20, 30]

# %%
l[0]
# Out:
# 16

# %%
l[-1]
# Out:
# 30

# %%
l[4]
# Out:
# 30

# %%
l
# Out:
# [16, 16, 10, 20, 30]

# %%
l[-4]
# Out:
# 16

# %%
l[-1]='jan'
l
# Out:
# [16, 16, 10, 20, 'jan']

# %%
l.append(20)
l
# Out:
# [16, 16, 10, 20, 'jan', 20]

# %%
len(l2)
# Out:
# 6

# %%
l2.clear()

# %%
l2
# Out:
# []

# %%
len(l2)
# Out:
# 0

# %%
del(l2)

# %%
l2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 l2
#
# NameError: name 'l2' is not defined

# %%
l
# Out:
# [16, 16, 10, 20, 'jan', 20]

# %%
l.count(10)
# Out:
# 1

# %%
l.count(100)
# Out:
# 0

# %%
print(l)
print(l1)
# Out:
# [16, 16, 10, 20, 'jan', 20]
# [10, 20, 30.5, 'ten', True, (1+2j)]

# %%
print(len(l))
print(len(l1))
# Out:
# 6
# 6

# %% [markdown]
# # list membership

# %%
l
# Out:
# [16, 16, 10, 20, 'jan', 20]

# %%
100 in l
# Out:
# False

# %%
16 in l
# Out:
# True

# %%
l1
# Out:
# [10, 20, 30.5, 'ten', True, (1+2j)]

# %%
20 in l1
# Out:
# True

# %%
100 in l1
# Out:
# False

# %%
l2=[]

# %%
l2
# Out:
# []

# %%
print(len(l))
print(len(l1))
print(len(l2))
# Out:
# 6
# 6
# 0

# %%
l2
# Out:
# []

# %%
l2.extend(l1)

# %%
l2
# Out:
# [10, 20, 30.5, 'ten', True, (1+2j)]

# %%
l1.extend(l2)
l1
# Out:
# [10, 20, 30.5, 'ten', True, (1+2j), 10, 20, 30.5, 'ten', True, (1+2j)]

# %%
l1
# Out:
# [10, 20, 30.5, 'ten', True, (1+2j), 10, 20, 30.5, 'ten', True, (1+2j)]

# %%
l
# Out:
# [16, 16, 10, 20, 'jan', 20]

# %%
l.index('jan')
# Out:
# 4

# %%
l
# Out:
# [16, 16, 10, 20, 'jan', 20]

# %%
l2[:]
# Out:
# [10, 20, 30.5, 'ten', True, (1+2j)]

# %%
l2
# Out:
# [10, 20, 30.5, 'ten', True, (1+2j)]

# %%
l2[0:2]
# Out:
# [10, 20]

# %%
l2[0:4]
# Out:
# [10, 20, 30.5, 'ten']

# %%
l2[0:5:2]
# Out:
# [10, 30.5, True]

# %%
l2[::2]
# Out:
# [10, 30.5, True]

# %% [markdown]
# # backward indexing & backward slicing

# %%
l2
# Out:
# [10, 20, 30.5, 'ten', True, (1+2j)]

# %%
l2[:]
# Out:
# [10, 20, 30.5, 'ten', True, (1+2j)]

# %%
l2[-5]
# Out:
# 20

# %%
l2[5]
# Out:
# (1+2j)

# %%
l2[:-3]
# Out:
# [10, 20, 30.5]

# %%
l2[-3:]
# Out:
# ['ten', True, (1+2j)]

# %%
l2[::-1]
# Out:
# [(1+2j), True, 'ten', 30.5, 20, 10]

# %%
l2[::-2]
# Out:
# [(1+2j), 'ten', 20]

# %%
l2[::3]
# Out:
# [10, 'ten']

# %%
l2
# Out:
# [10, 20, 30.5, 'ten', True, (1+2j)]
