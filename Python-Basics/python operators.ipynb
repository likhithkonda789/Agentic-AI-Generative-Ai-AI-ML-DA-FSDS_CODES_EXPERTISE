# %% [markdown]
# python operators
#
# # 1.arithmetic operator

# %%
x1,y1=17,5

# %%
x1+y1
# Out:
# 22

# %%
x1-y1
# Out:
# 12

# %%
x1*y1
# Out:
# 85

# %%
x1/y1
# Out:
# 3.4

# %%
x1,y1=10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 x1,y1=10
#
# TypeError: cannot unpack non-iterable int object

# %%
x1,y1=6,"ten"

# %%
a=x1+y1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 a=x1+y1
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
x1,y1=17,5

# %%
x1//y1
# Out:
# 3

# %%
x1%y1
# Out:
# 2

# %%
x1**y1
# Out:
# 1419857

# %%
3**3
# Out:
# 27

# %%
x1^y1
# Out:
# 20

# %% [markdown]
# # 2, assignment operator

# %%
x=2

# %%
x=x+4

# %%
x
# Out:
# 6

# %%
x+=1
x
# Out:
# 7

# %%
x-=1
x
# Out:
# 6

# %%
x*=3
x
# Out:
# 18

# %%
x/=2
x
# Out:
# 9.0

# %%
x//=2
x
# Out:
# 4.0

# %% [markdown]
# # 3.unary operator

# %%
n=6
n
# Out:
# 6

# %%
m = -(n)
m
# Out:
# -6

# %%
n
# Out:
# 6

# %%
-n
# Out:
# -6

# %% [markdown]
# # 4. relational operator

# %%
a=5
b=6

# %%
a<b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
a==b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
a=6
b=6

# %%
a<b
# Out:
# False

# %%
a>b
# Out:
# False

# %%
a==b
# Out:
# True

# %%
a!=b
# Out:
# False

# %%
a
# Out:
# 6

# %%
b
# Out:
# 6

# %%
a<=b
# Out:
# True

# %%
a>=b
# Out:
# True

# %% [markdown]
# # 5.logical operator

# %%
a=6
b=5

# %%
a<8 and b<4
# Out:
# False

# %%
a<8 and b<6
# Out:
# True

# %%
a>7 and b>7
# Out:
# False

# %%
a>3 and b>3
# Out:
# True

# %%
a<4 or b<3
# Out:
# False

# %%
a<7 or b<7
# Out:
# True

# %%
a>3 or b>3
# Out:
# True

# %%
a>7 or b>7
# Out:
# False

# %%
x= False
x
# Out:
# False

# %%
not x
# Out:
# True

# %%
x=not x
x
# Out:
# True

# %%
not x
# Out:
# False

# %% [markdown]
# # python bitwise operator

# %%
~6
# Out:
# -7

# %%
~35
# Out:
# -36

# %% [markdown]
# # binary number system

# %%
25
# Out:
# 25

# %%
bin (25)
# Out:
# '0b11001'

# %%
0b11001
# Out:
# 25

# %% [markdown]
# # 21st

# %%
bin(30)
# Out:
# '0b11110'

# %%
int(0b11110)
# Out:
# 30

# %% [markdown]
# # octal number system

# %%
oct (25)
# Out:
# '0o31'

# %%
int(0o31)
# Out:
# 25

# %%
0o31
# Out:
# 25

# %% [markdown]
# # hexa decimal number system

# %%
hex(16)
# Out:
# '0x10'

# %%
0xb
# Out:
# 11

# %%
hex(14)
# Out:
# '0xe'

# %%
hex(10)
# Out:
# '0xa'

# %%
0x10
# Out:
# 16

# %% [markdown]
# # bitwise And , Or operators

# %%
12&13
# Out:
# 12

# %%
12|13
# Out:
# 13

# %%
1&0
# Out:
# 0

# %%
 1|0
# Out:
# 1

# %%
bin (13)
# Out:
# '0b1101'

# %%
print(bin(35))
print(bin(40))
# Out:
# 0b100011
# 0b101000

# %%
35&40
# Out:
# 32

# %% [markdown]
# # Xor operator

# %%
12^13
# Out:
# 1

# %%
print (bin(25))
print(bin(30))
# Out:
# 0b11001
# 0b11110

# %%
25^30
# Out:
# 7

# %%
bin(7)
# Out:
# '0b111'

# %%
bin(25)
# Out:
# '0b11001'

# %% [markdown]
# # leftshift and Rightshift operators

# %%
bin(10)
# Out:
# '0b1010'

# %%
10<<1
# Out:
# 20

# %%
10<<2
# Out:
# 40

# %%
bin(40)
# Out:
# '0b101000'

# %%
10<<3
# Out:
# 80

# %%
bin(10)
# Out:
# '0b1010'

# %%
bin(3)
# Out:
# '0b11'

# %%
bin(80)
# Out:
# '0b1010000'

# %%
bin(20)
# Out:
# '0b10100'

# %%
20<<4
# Out:
# 320

# %%
10>>1
# Out:
# 5

# %%
bin(5)
# Out:
# '0b101'

# %%
bin(10)
# Out:
# '0b1010'

# %%
10>>2
# Out:
# 2

# %%
10>>4
# Out:
# 0

# %% [markdown]
#  # print()

# %%
print(10)
print(20.39)
print('python')
print(10,20,'python',True,2,3,[1,2])
# Out:
# 10
# 20.39
# python
# 10 20 python True 2 3 [1, 2]

# %%
# print result with string

# %%
num1=20 
num2=30
add =num1+num2
print( 'The addition of ',num1,'and',num2,'is=',add)
# Out:
# The addition of  20 and 30 is= 50

# %%
num1=20 
num2=30
add =num1+num2
print(add)
# Out:
# 50
