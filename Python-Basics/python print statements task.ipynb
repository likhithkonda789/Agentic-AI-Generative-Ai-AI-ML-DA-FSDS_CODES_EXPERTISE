# %%
# print it use for answer

# %%
a=59
b=57
a
b
# Out:
# 57

# %%
a=59
b=57
print(a)
print(b)
# Out:
# 59
# 57

# %%
num1=50
num2=50
add =num1+num2
print(add)
# Out:
# 100

# %% [markdown]
# # print result with string

# %%
num1=50
num2=60
add =num1+num2
print('the addition of',num1,'and',num2,'is=',add)
# Out:
# the addition of 50 and 60 is= 110

# %%
name='likhith' 
age=23
city='hnk'

# %%
print ('my name is', name,'and i am', age,'years old from', city)
# Out:
# my name is likhith and i am 23 years old from hnk

# %% [markdown]
# # print format method

# %%
 
num1=60
num2=6 
add=num1+num2 
print('The addition of {} and {} is= {}'.format(num1,num2,add))
# Out:
# The addition of 60 and 6 is= 66

# %%
name='Python' 
age=20 
city='hyd'

# %%
print('hello my name is {}, and i am {} years old from {} '
.format(name,age,city))
# Out:
# hello my name is Python, and i am 20 years old from hyd

# %% [markdown]
# # more short format method (f string method)

# %%
num1=2.6
num2=4.4
add =num1+num2
print(f'the addition of {num1} and {num2} is = {add}')
# Out:
# the addition of 2.6 and 4.4 is = 7.0

# %%
name='likhith' 
age=23
city='hnk'

# %%
print (f'hello my name is { name}, and iam {age} year old ,from {city},')
# Out:
# hello my name is likhith, and iam 23 year old ,from hnk,

# %% [markdown]
# # end statement

# %%
print ('hi')
print('im likhith')
# Out:
# hi
# im likhith

# %%
print ('hi',end ='')
print(' im likhith')
# Out:
# hi im likhith

# %% [markdown]
# # seprator

# %%
print('hello','im likhith','how are you ' ,sep='--->')
# Out:
# hello--->im likhith--->how are you

# %%
print('hello','hai','how are you ' ,sep='&')
# Out:
# hello&hai&how are you

# %%
print('hello','im likhith','how are you ' ,sep='@')
# Out:
# hello@im likhith@how are you

# %%
print('hello','im likhith','how are you ' ,sep=' ')
# Out:
# hello im likhith how are you
