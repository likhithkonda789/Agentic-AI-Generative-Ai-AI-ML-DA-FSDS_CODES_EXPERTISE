# %% [markdown]
# # python program to generate otp

# %%
import random

def generate_otp(length=4):
    """Generate a numeric OTP of a specified length."""
    digits = '012345'
    otp = ''.join(random.choice(digits) for _ in range(length))
    return otp

# Example usage
otp_length = 4  # You can change this to any length you prefer
otp = generate_otp(otp_length)
print(f"Your OTP is: {otp}")
# Out:
# Your OTP is: 4455

# %%
def wish():
    print('good morning')
wish()

def wish():
    print('good afternoon')
wish()

def wish():
    print('good evening')
wish()
# Out:
# good morning
# good afternoon
# good evening

# %%
def wish():
    print('good evening')
wish()

wish()

wish()
# Out:
# good evening
# good evening
# good evening

# %%
def wish():
    print('good morning')
wish()

wish()

wish()
# Out:
# good morning
# good morning
# good morning

# %%
list1=['a','b','g',1,5]
print(list1.pop)
# Out:
# <built-in method pop of list object at 0x000002A358065AC0>

# %%
x = [1, 2, 3]
y = x.copy()
x.append(4)
print(x)
# Out:
# [1, 2, 3, 4]
