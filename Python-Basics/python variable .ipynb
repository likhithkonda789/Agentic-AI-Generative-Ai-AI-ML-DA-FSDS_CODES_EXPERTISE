# %%
import sys
sys.version
# Out:
# '3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 16:37:03) [MSC v.1929 64 bit (AMD64)]'

# %% [markdown]
# # python variable =identifier=object
# # syntax(variable=value)

# %%
v=8

# %%
v
# Out:
# 8

# %% [markdown]
# # Rules to declare python variable

# %%
var = 8
VAR
# Out:
# 8

# %%
v@ =12
v@
# Out:
#   Cell In[13], line 1
#     v@ =12
#        ^
# SyntaxError: invalid syntax

# %%
v_ = 12
v_
# Out:
# 12

# %%
1var =12
1var
# Out:
#   Cell In[15], line 1
#     1var =12
#     ^
# SyntaxError: invalid decimal literal

# %%
var1 =10
var1
# Out:
# 10

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len ( keyword.kwlist)
# Out:
# 35

# %%
for = 8
# Out:
#   Cell In[25], line 1
#     for = 8
#         ^
# SyntaxError: invalid syntax

# %%
def =14
# Out:
#   Cell In[26], line 1
#     def =14
#         ^
# SyntaxError: invalid syntax

# %%
DEF=10
DEF
# Out:
# 10

# %% [markdown]
# # python variable

# %%
# integer variable

# %%
age =23
age
# Out:
# 23

# %%
age =23
print (age)
# Out:
# 23

# %%
# string variable

# %%
name = likhith
print (name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 name = likhith
#       2 print (name)
#
# NameError: name 'likhith' is not defined

# %%
name = 'likhith'
print (name)
# Out:
# likhith

# %%
# float variable

# %%
price = 13.9
print (price)
# Out:
# 13.9

# %%
# boolean variable

# %%
is_active=True
print(is_active)
# Out:
# True

# %% [markdown]
# # storing and printing values

# %%
x=17
x
# Out:
# 17

# %% [markdown]
# # using variables in expressions

# %%
# assigning values to variables

# %%
a=6

# %%
b=6

# %%
result =a+b

# %%
print (result)
# Out:
# 12

# %% [markdown]
# # changing the values of variables

# %%
# initial values

# %%
score =60

# %%
print ( score)
# Out:
# 60

# %%
# changing the value of score

# %%
score =100

# %%
print (score)
# Out:
# 100

# %% [markdown]
# # concatenating stings

# %%
first_name ="likhith"
last_name="konda"
full_name=first_name+""+last_name
print (full_name)
# Out:
# likhithkonda

# %% [markdown]
# # using calculation in variables

# %%
# assinging values to variables

# %%
lenth =10

# %%
width =5

# %%
#calculating the area of rectangle

# %%
area = lenth*width

# %%
print (area)
# Out:
# 50

# %% [markdown]
# # reassining the values to variables

# %%
x=10

# %%
print(x)
# Out:
# 10

# %%
# reassinging the values

# %%
x=20

# %%
print(x)
# Out:
# 20
