# %% [markdown]
# ### 16 October 2025

# %%
#Float
1e0
# Out:
# 1.0

# %%
f = 1e0
f
# Out:
# 1.0

# %%
f1 = 2e1
f1
# Out:
# 20.0

# %%
f2 = 2.4e2
f2
# Out:
# 240.0

# %%
f3 = 2.5e3
f3
# Out:
# 2500.0

# %%
   type(f3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 type(f3)
#
# NameError: name 'f3' is not defined

# %%
import numpy as np
a = np.nan
type(a)
# Out:
# float

# %% [markdown]
# ## slicing and indexing
# 17 OCT 2025

# %%
i = 34
i
# Out:
# 34

# %%
id(i)
# Out:
# 140715211732936

# %%
p = 20
q = 20
r = 20

# %%
print(id(p))
# Out:
# 140715211732488

# %%
print(id(q))
# Out:
# 140715211732488

# %%
print(id(r))
# Out:
# 140715211732488

# %%
r = 30
id(r)
# Out:
# 140715211732808

# %%
str = 'hello'
str
# Out:
# 'hello'

# %%
str[0]
# Out:
# 'h'

# %%
str[1]
# Out:
# 'e'

# %%
str[4]
# Out:
# 'o'

# %%
print(str[0])
print(str[1])
print(str[2])
print(str[3])
print(str[4])
# Out:
# h
# e
# l
# l
# o

# %%
str
# Out:
# 'hello'

# %%
print(str[-1])
print(str[-2])
print(str[-3])
print(str[-4])
print(str[-5])
# Out:
# o
# l
# l
# e
# h

# %%
str
# Out:
# 'hello'

# %%
len(str)
# Out:
# 5

# %%
str
# Out:
# 'hello'

# %%
str[1:3]
# Out:
# 'el'

# %%
str
# Out:
# 'hello'

# %%
str[0:4]
# Out:
# 'hell'

# %%
s = 'hellopython'
s
# Out:
# 'hellopython'

# %%
s[0:6]
# Out:
# 'hellop'

# %%
s
# Out:
# 'hellopython'

# %%
s[0:10:3]
# Out:
# 'hlyo'

# %%
s
# Out:
# 'hellopython'

# %%
s[1:8:2]
# Out:
# 'elpt'

# %%
# Backward indexing
s
# Out:
# 'hellopython'

# %%
s[::1]
# Out:
# 'hellopython'

# %%
s[::2]
# Out:
# 'hloyhn'

# %%
s[::3]
# Out:
# 'hlyo'

# %%
s[:]
# Out:
# 'hellopython'

# %%
s3 = 'hello'
s4 = 'hi'

print(s3+s4)
# Out:
# hellohi

# %%
s3 = 'hello'
s4 = ' hi'

print(s3+s4)
# Out:
# hello hi
